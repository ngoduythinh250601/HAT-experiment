# %% [markdown]
# ## Mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Gen LR

# %%
# !mkdir -p /content/datasets/Human_Faces

# %%
# !unzip /content/drive/MyDrive/Datasets/train/Human_Faces_train_HR.zip -d /content/datasets/Human_Faces

# %%
# -*- coding: utf-8 -*-
import math
import numpy as np
import cv2
import torch

import random
from scipy import ndimage
import scipy
import scipy.stats as ss
from scipy.interpolate import interp2d
from scipy.linalg import orth

def modcrop_np(img, sf):
    '''
    Args:
        img: numpy image, WxH or WxHxC
        sf: scale factor

    Return:
        cropped image
    '''
    w, h = img.shape[:2]
    im = np.copy(img)
    return im[:w - w % sf, :h - h % sf, ...]


"""
# --------------------------------------------
# anisotropic Gaussian kernels
# --------------------------------------------
"""
def analytic_kernel(k):
    """Calculate the X4 kernel from the X2 kernel (for proof see appendix in paper)"""
    k_size = k.shape[0]
    # Calculate the big kernels size
    big_k = np.zeros((3 * k_size - 2, 3 * k_size - 2))
    # Loop over the small kernel to fill the big one
    for r in range(k_size):
        for c in range(k_size):
            big_k[2 * r:2 * r + k_size, 2 * c:2 * c + k_size] += k[r, c] * k
    # Crop the edges of the big kernel to ignore very small values and increase run time of SR
    crop = k_size // 2
    cropped_big_k = big_k[crop:-crop, crop:-crop]
    # Normalize to 1
    return cropped_big_k / cropped_big_k.sum()


def anisotropic_Gaussian(ksize=15, theta=np.pi, l1=6, l2=6):
    """ generate an anisotropic Gaussian kernel
    Args:
        ksize : e.g., 15, kernel size
        theta : [0,  pi], rotation angle range
        l1    : [0.1,50], scaling of eigenvalues
        l2    : [0.1,l1], scaling of eigenvalues
        If l1 = l2, will get an isotropic Gaussian kernel.

    Returns:
        k     : kernel
    """

    v = np.dot(np.array([[np.cos(theta), -np.sin(theta)], [np.sin(theta), np.cos(theta)]]), np.array([1., 0.]))
    V = np.array([[v[0], v[1]], [v[1], -v[0]]])
    D = np.array([[l1, 0], [0, l2]])
    Sigma = np.dot(np.dot(V, D), np.linalg.inv(V))
    k = gm_blur_kernel(mean=[0, 0], cov=Sigma, size=ksize)

    return k


def gm_blur_kernel(mean, cov, size=15):
    center = size / 2.0 + 0.5
    k = np.zeros([size, size])
    for y in range(size):
        for x in range(size):
            cy = y - center + 1
            cx = x - center + 1
            k[y, x] = ss.multivariate_normal.pdf([cx, cy], mean=mean, cov=cov)

    k = k / np.sum(k)
    return k


def shift_pixel(x, sf, upper_left=True):
    """shift pixel for super-resolution with different scale factors
    Args:
        x: WxHxC or WxH
        sf: scale factor
        upper_left: shift direction
    """
    h, w = x.shape[:2]
    shift = (sf-1)*0.5
    xv, yv = np.arange(0, w, 1.0), np.arange(0, h, 1.0)
    if upper_left:
        x1 = xv + shift
        y1 = yv + shift
    else:
        x1 = xv - shift
        y1 = yv - shift

    x1 = np.clip(x1, 0, w-1)
    y1 = np.clip(y1, 0, h-1)

    if x.ndim == 2:
        x = interp2d(xv, yv, x)(x1, y1)
    if x.ndim == 3:
        for i in range(x.shape[-1]):
            x[:, :, i] = interp2d(xv, yv, x[:, :, i])(x1, y1)

    return x


def blur(x, k):
    '''
    x: image, NxcxHxW
    k: kernel, Nx1xhxw
    '''
    n, c = x.shape[:2]
    p1, p2 = (k.shape[-2]-1)//2, (k.shape[-1]-1)//2
    x = torch.nn.functional.pad(x, pad=(p1, p2, p1, p2), mode='replicate')
    k = k.repeat(1,c,1,1)
    k = k.view(-1, 1, k.shape[2], k.shape[3])
    x = x.view(1, -1, x.shape[2], x.shape[3])
    x = torch.nn.functional.conv2d(x, k, bias=None, stride=1, padding=0, groups=n*c)
    x = x.view(n, c, x.shape[2], x.shape[3])

    return x



def gen_kernel(k_size=np.array([15, 15]), scale_factor=np.array([4, 4]), min_var=0.6, max_var=10., noise_level=0):
    """"
    # modified version of https://github.com/assafshocher/BlindSR_dataset_generator
    # Kai Zhang
    # min_var = 0.175 * sf  # variance of the gaussian kernel will be sampled between min_var and max_var
    # max_var = 2.5 * sf
    """
    # Set random eigen-vals (lambdas) and angle (theta) for COV matrix
    lambda_1 = min_var + np.random.rand() * (max_var - min_var)
    lambda_2 = min_var + np.random.rand() * (max_var - min_var)
    theta = np.random.rand() * np.pi  # random theta
    noise = -noise_level + np.random.rand(*k_size) * noise_level * 2

    # Set COV matrix using Lambdas and Theta
    LAMBDA = np.diag([lambda_1, lambda_2])
    Q = np.array([[np.cos(theta), -np.sin(theta)],
                  [np.sin(theta), np.cos(theta)]])
    SIGMA = Q @ LAMBDA @ Q.T
    INV_SIGMA = np.linalg.inv(SIGMA)[None, None, :, :]

    # Set expectation position (shifting kernel for aligned image)
    MU = k_size // 2 - 0.5*(scale_factor - 1) # - 0.5 * (scale_factor - k_size % 2)
    MU = MU[None, None, :, None]

    # Create meshgrid for Gaussian
    [X,Y] = np.meshgrid(range(k_size[0]), range(k_size[1]))
    Z = np.stack([X, Y], 2)[:, :, :, None]

    # Calcualte Gaussian for every pixel of the kernel
    ZZ = Z-MU
    ZZ_t = ZZ.transpose(0,1,3,2)
    raw_kernel = np.exp(-0.5 * np.squeeze(ZZ_t @ INV_SIGMA @ ZZ)) * (1 + noise)

    # shift the kernel so it will be centered
    #raw_kernel_centered = kernel_shift(raw_kernel, scale_factor)

    # Normalize the kernel and return
    #kernel = raw_kernel_centered / np.sum(raw_kernel_centered)
    kernel = raw_kernel / np.sum(raw_kernel)
    return kernel


def fspecial_gaussian(hsize, sigma):
    hsize = [hsize, hsize]
    siz = [(hsize[0]-1.0)/2.0, (hsize[1]-1.0)/2.0]
    std = sigma
    [x, y] = np.meshgrid(np.arange(-siz[1], siz[1]+1), np.arange(-siz[0], siz[0]+1))
    arg = -(x*x + y*y)/(2*std*std)
    h = np.exp(arg)
    h[h < scipy.finfo(float).eps * h.max()] = 0
    sumh = h.sum()
    if sumh != 0:
        h = h/sumh
    return h


def fspecial_laplacian(alpha):
    alpha = max([0, min([alpha,1])])
    h1 = alpha/(alpha+1)
    h2 = (1-alpha)/(alpha+1)
    h = [[h1, h2, h1], [h2, -4/(alpha+1), h2], [h1, h2, h1]]
    h = np.array(h)
    return h


def fspecial(filter_type, *args, **kwargs):
    '''
    python code from:
    https://github.com/ronaldosena/imagens-medicas-2/blob/40171a6c259edec7827a6693a93955de2bd39e76/Aulas/aula_2_-_uniform_filter/matlab_fspecial.py
    '''
    if filter_type == 'gaussian':
        return fspecial_gaussian(*args, **kwargs)
    if filter_type == 'laplacian':
        return fspecial_laplacian(*args, **kwargs)

"""
# --------------------------------------------
# degradation models
# --------------------------------------------
"""


def bicubic_degradation(x, sf=3):
    '''
    Args:
        x: HxWxC image, [0, 1]
        sf: down-scale factor

    Return:
        bicubicly downsampled LR image
    '''
    x = imresize_np(x, scale=1/sf)
    return x


def srmd_degradation(x, k, sf=3):
    ''' blur + bicubic downsampling

    Args:
        x: HxWxC image, [0, 1]
        k: hxw, double
        sf: down-scale factor

    Return:
        downsampled LR image

    Reference:
        @inproceedings{zhang2018learning,
          title={Learning a single convolutional super-resolution network for multiple degradations},
          author={Zhang, Kai and Zuo, Wangmeng and Zhang, Lei},
          booktitle={IEEE Conference on Computer Vision and Pattern Recognition},
          pages={3262--3271},
          year={2018}
        }
    '''
    x = ndimage.filters.convolve(x, np.expand_dims(k, axis=2), mode='wrap')  # 'nearest' | 'mirror'
    x = bicubic_degradation(x, sf=sf)
    return x


def dpsr_degradation(x, k, sf=3):

    ''' bicubic downsampling + blur

    Args:
        x: HxWxC image, [0, 1]
        k: hxw, double
        sf: down-scale factor

    Return:
        downsampled LR image

    Reference:
        @inproceedings{zhang2019deep,
          title={Deep Plug-and-Play Super-Resolution for Arbitrary Blur Kernels},
          author={Zhang, Kai and Zuo, Wangmeng and Zhang, Lei},
          booktitle={IEEE Conference on Computer Vision and Pattern Recognition},
          pages={1671--1681},
          year={2019}
        }
    '''
    x = bicubic_degradation(x, sf=sf)
    x = ndimage.filters.convolve(x, np.expand_dims(k, axis=2), mode='wrap')
    return x


def classical_degradation(x, k, sf=3):
    ''' blur + downsampling

    Args:
        x: HxWxC image, [0, 1]/[0, 255]
        k: hxw, double
        sf: down-scale factor

    Return:
        downsampled LR image
    '''
    x = ndimage.filters.convolve(x, np.expand_dims(k, axis=2), mode='wrap')
    #x = filters.correlate(x, np.expand_dims(np.flip(k), axis=2))
    st = 0
    return x[st::sf, st::sf, ...]


def add_sharpening(img, weight=0.5, radius=50, threshold=10):
    """USM sharpening. borrowed from real-ESRGAN
    Input image: I; Blurry image: B.
    1. K = I + weight * (I - B)
    2. Mask = 1 if abs(I - B) > threshold, else: 0
    3. Blur mask:
    4. Out = Mask * K + (1 - Mask) * I
    Args:
        img (Numpy array): Input image, HWC, BGR; float32, [0, 1].
        weight (float): Sharp weight. Default: 1.
        radius (float): Kernel size of Gaussian blur. Default: 50.
        threshold (int):
    """
    if radius % 2 == 0:
        radius += 1
    blur = cv2.GaussianBlur(img, (radius, radius), 0)
    residual = img - blur
    mask = np.abs(residual) * 255 > threshold
    mask = mask.astype('float32')
    soft_mask = cv2.GaussianBlur(mask, (radius, radius), 0)

    K = img + weight * residual
    K = np.clip(K, 0, 1)
    return soft_mask * K + (1 - soft_mask) * img


def add_blur(img, sf=4):
    wd2 = 4.0 + sf
    wd = 2.0 + 0.2*sf
    if random.random() < 0.5:
        l1 = wd2*random.random()
        l2 = wd2*random.random()
        k = anisotropic_Gaussian(ksize=2*random.randint(2,11)+3, theta=random.random()*np.pi, l1=l1, l2=l2)
    else:
        k = fspecial('gaussian', 2*random.randint(2,11)+3, wd*random.random())
    img = ndimage.filters.convolve(img, np.expand_dims(k, axis=2), mode='mirror')

    return img


def add_resize(img, sf=4):
    rnum = np.random.rand()
    if rnum > 0.8:  # up
        sf1 = random.uniform(1, 2)
    elif rnum < 0.7:  # down
        sf1 = random.uniform(0.5/sf, 1)
    else:
        sf1 = 1.0
    img = cv2.resize(img, (int(sf1*img.shape[1]), int(sf1*img.shape[0])), interpolation=random.choice([1, 2, 3]))
    img = np.clip(img, 0.0, 1.0)

    return img


def add_Gaussian_noise(img, noise_level1=2, noise_level2=25):
    noise_level = random.randint(noise_level1, noise_level2)
    rnum = np.random.rand()
    if rnum > 0.6:   # add color Gaussian noise
        img += np.random.normal(0, noise_level/255.0, img.shape).astype(np.float32)
    elif rnum < 0.4: # add grayscale Gaussian noise
        img += np.random.normal(0, noise_level/255.0, (*img.shape[:2], 1)).astype(np.float32)
    else:            # add  noise
        L = noise_level2/255.
        D = np.diag(np.random.rand(3))
        U = orth(np.random.rand(3,3))
        conv = np.dot(np.dot(np.transpose(U), D), U)
        img += np.random.multivariate_normal([0,0,0], np.abs(L**2*conv), img.shape[:2]).astype(np.float32)
    img = np.clip(img, 0.0, 1.0)
    return img


def add_speckle_noise(img, noise_level1=2, noise_level2=25):
    noise_level = random.randint(noise_level1, noise_level2)
    img = np.clip(img, 0.0, 1.0)
    rnum = random.random()
    if rnum > 0.6:
        img += img*np.random.normal(0, noise_level/255.0, img.shape).astype(np.float32)
    elif rnum < 0.4:
        img += img*np.random.normal(0, noise_level/255.0, (*img.shape[:2], 1)).astype(np.float32)
    else:
        L = noise_level2/255.
        D = np.diag(np.random.rand(3))
        U = orth(np.random.rand(3,3))
        conv = np.dot(np.dot(np.transpose(U), D), U)
        img += img*np.random.multivariate_normal([0,0,0], np.abs(L**2*conv), img.shape[:2]).astype(np.float32)
    img = np.clip(img, 0.0, 1.0)
    return img


def add_Poisson_noise(img):
    img = np.clip((img * 255.0).round(), 0, 255) / 255.
    vals = 10**(2*random.random()+2.0)  # [2, 4]
    if random.random() < 0.5:
        img = np.random.poisson(img * vals).astype(np.float32) / vals
    else:
        img_gray = np.dot(img[...,:3], [0.299, 0.587, 0.114])
        img_gray = np.clip((img_gray * 255.0).round(), 0, 255) / 255.
        noise_gray = np.random.poisson(img_gray * vals).astype(np.float32) / vals - img_gray
        img += noise_gray[:, :, np.newaxis]
    img = np.clip(img, 0.0, 1.0)
    return img


def add_JPEG_noise(img):
    quality_factor = random.randint(30, 95)
    img = cv2.cvtColor(single2uint(img), cv2.COLOR_RGB2BGR)
    result, encimg = cv2.imencode('.jpg', img, [int(cv2.IMWRITE_JPEG_QUALITY), quality_factor])
    img = cv2.imdecode(encimg, 1)
    img = cv2.cvtColor(uint2single(img), cv2.COLOR_BGR2RGB)
    return img


def random_crop(lq, hq, sf=4, lq_patchsize=64):
    h, w = lq.shape[:2]
    rnd_h = random.randint(0, h-lq_patchsize)
    rnd_w = random.randint(0, w-lq_patchsize)
    lq = lq[rnd_h:rnd_h + lq_patchsize, rnd_w:rnd_w + lq_patchsize, :]

    rnd_h_H, rnd_w_H = int(rnd_h * sf), int(rnd_w * sf)
    hq = hq[rnd_h_H:rnd_h_H + lq_patchsize*sf, rnd_w_H:rnd_w_H + lq_patchsize*sf, :]
    return lq, hq


def degradation_bsrgan(img, sf=4, isp_model=None):
    isp_prob, jpeg_prob, scale2_prob = 0.1, 0.0, 0.0
    sf_ori = sf

    h1, w1 = img.shape[:2]
    img = img.copy()[:h1 - h1 % sf, :w1 - w1 % sf, ...]  # mod crop
    h, w = img.shape[:2]

    hq = img.copy()

    if sf == 4 and random.random() < scale2_prob:   # downsample1
        if np.random.rand() < 0.5:
            img = cv2.resize(img, (int(1/2*img.shape[1]), int(1/2*img.shape[0])), interpolation=random.choice([1,2,3]))
        else:
            img = imresize_np(img, 1/2, True)
        img = np.clip(img, 0.0, 1.0)
        sf = 2

    shuffle_order = random.sample(range(7), 7)
    idx1, idx2 = shuffle_order.index(2), shuffle_order.index(3)
    if idx1 > idx2:  # keep downsample3 last
        shuffle_order[idx1], shuffle_order[idx2] = shuffle_order[idx2], shuffle_order[idx1]

    for i in shuffle_order:

        if i == 0:
            img = add_blur(img, sf=sf)

        elif i == 1:
            img = add_blur(img, sf=sf)

        elif i == 2:
            a, b = img.shape[1], img.shape[0]
            # downsample2
            if random.random() < 0.75:
                sf1 = random.uniform(1,2*sf)
                img = cv2.resize(img, (int(1/sf1*img.shape[1]), int(1/sf1*img.shape[0])), interpolation=random.choice([1,2,3]))
            else:
                k = fspecial('gaussian', 25, random.uniform(0.1, 0.6*sf))
                k_shifted = shift_pixel(k, sf)
                k_shifted = k_shifted/k_shifted.sum()  # blur with shifted kernel
                img = ndimage.filters.convolve(img, np.expand_dims(k_shifted, axis=2), mode='mirror')
                img = img[0::sf, 0::sf, ...]  # nearest downsampling
            img = np.clip(img, 0.0, 1.0)

        elif i == 3:
            # downsample3
            img = cv2.resize(img, (int(1/sf*a), int(1/sf*b)), interpolation=random.choice([1,2,3]))
            img = np.clip(img, 0.0, 1.0)

        elif i == 4:
            # add Gaussian noise
            img = add_Gaussian_noise(img, noise_level1=2, noise_level2=25)

        elif i == 5:
            # add JPEG noise
            if random.random() < jpeg_prob:
                img = add_JPEG_noise(img)

        elif i == 6:
            # add processed camera sensor noise
            if random.random() < isp_prob and isp_model is not None:
                with torch.no_grad():
                    img, hq = isp_model.forward(img.copy(), hq)

    # add final JPEG compression noise
    img = add_JPEG_noise(img)

    # random crop
    # img, hq = random_crop(img, hq, sf_ori, lq_patchsize)

    print(img.shape)
    print(hq.shape)
    return img, hq




def degradation_bsrgan_plus(img, sf=4, shuffle_prob=0.5, use_sharp=True, lq_patchsize=64, isp_model=None):
    """
    This is an extended degradation model by combining
    the degradation models of BSRGAN and Real-ESRGAN
    ----------
    img: HXWXC, [0, 1], its size should be large than (lq_patchsizexsf)x(lq_patchsizexsf)
    sf: scale factor
    use_shuffle: the degradation shuffle
    use_sharp: sharpening the img

    Returns
    -------
    img: low-quality patch, size: lq_patchsizeXlq_patchsizeXC, range: [0, 1]
    hq: corresponding high-quality patch, size: (lq_patchsizexsf)X(lq_patchsizexsf)XC, range: [0, 1]
    """

    h1, w1 = img.shape[:2]
    img = img.copy()[:h1 - h1 % sf, :w1 - w1 % sf, ...]  # mod crop
    h, w = img.shape[:2]

    if h < lq_patchsize*sf or w < lq_patchsize*sf:
        raise ValueError(f'img size ({h1}X{w1}) is too small!')

    if use_sharp:
        img = add_sharpening(img)
    hq = img.copy()

    if random.random() < shuffle_prob:
        shuffle_order = random.sample(range(13), 13)
    else:
        shuffle_order = list(range(13))
        # local shuffle for noise, JPEG is always the last one
        shuffle_order[2:6] = random.sample(shuffle_order[2:6], len(range(2, 6)))
        shuffle_order[9:13] = random.sample(shuffle_order[9:13], len(range(9, 13)))

    poisson_prob, speckle_prob, isp_prob = 0.1, 0.1, 0.1

    for i in shuffle_order:
        if i == 0:
            img = add_blur(img, sf=sf)
        elif i == 1:
            img = add_resize(img, sf=sf)
        elif i == 2:
            img = add_Gaussian_noise(img, noise_level1=2, noise_level2=25)
        elif i == 3:
            if random.random() < poisson_prob:
                img = add_Poisson_noise(img)
        elif i == 4:
            if random.random() < speckle_prob:
                img = add_speckle_noise(img)
        elif i == 5:
            if random.random() < isp_prob and isp_model is not None:
                with torch.no_grad():
                    img, hq = isp_model.forward(img.copy(), hq)
        elif i == 6:
            img = add_JPEG_noise(img)
        elif i == 7:
            img = add_blur(img, sf=sf)
        elif i == 8:
            img = add_resize(img, sf=sf)
        elif i == 9:
            img = add_Gaussian_noise(img, noise_level1=2, noise_level2=25)
        elif i == 10:
            if random.random() < poisson_prob:
                img = add_Poisson_noise(img)
        elif i == 11:
            if random.random() < speckle_prob:
                img = add_speckle_noise(img)
        elif i == 12:
            if random.random() < isp_prob and isp_model is not None:
                with torch.no_grad():
                    img, hq = isp_model.forward(img.copy(), hq)
        else:
            print('check the shuffle!')

    # resize to desired size
    img = cv2.resize(img, (int(1/sf*hq.shape[1]), int(1/sf*hq.shape[0])), interpolation=random.choice([1, 2, 3]))

    # add final JPEG compression noise
    img = add_JPEG_noise(img)

    # random crop
    img, hq = random_crop(img, hq, sf, lq_patchsize)

    return img, hq

def imread_uint(path, n_channels=3):
    #  input: path
    # output: HxWx3(RGB or GGG), or HxWx1 (G)
    if n_channels == 1:
        img = cv2.imread(path, 0)  # cv2.IMREAD_GRAYSCALE
        img = np.expand_dims(img, axis=2)  # HxWx1
    elif n_channels == 3:
        img = cv2.imread(path, cv2.IMREAD_UNCHANGED)  # BGR or G
        if img.ndim == 2:
            img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)  # GGG
        else:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # RGB
    return img

def uint2single(img):
    return np.float32(img/255.)

def single2uint(img):
    return np.uint8((img.clip(0, 1)*255.).round())

def imsave(img, img_path):
    img = np.squeeze(img)
    if img.ndim == 3:
        img = img[:, :, [2, 1, 0]]
    cv2.imwrite(img_path, img)

def imresize_np(img, scale, antialiasing=True):
    # Now the scale should be the same for H and W
    # input: img: Numpy, HWC or HW [0,1]
    # output: HWC or HW [0,1] w/o round
    img = torch.from_numpy(img)
    need_squeeze = True if img.dim() == 2 else False
    if need_squeeze:
        img.unsqueeze_(2)

    in_H, in_W, in_C = img.size()
    out_C, out_H, out_W = in_C, math.ceil(in_H * scale), math.ceil(in_W * scale)
    kernel_width = 4
    kernel = 'cubic'

    # Return the desired dimension order for performing the resize.  The
    # strategy is to perform the resize first along the dimension with the
    # smallest scale factor.
    # Now we do not support this.

    # get weights and indices
    weights_H, indices_H, sym_len_Hs, sym_len_He = calculate_weights_indices(
        in_H, out_H, scale, kernel, kernel_width, antialiasing)
    weights_W, indices_W, sym_len_Ws, sym_len_We = calculate_weights_indices(
        in_W, out_W, scale, kernel, kernel_width, antialiasing)
    # process H dimension
    # symmetric copying
    img_aug = torch.FloatTensor(in_H + sym_len_Hs + sym_len_He, in_W, in_C)
    img_aug.narrow(0, sym_len_Hs, in_H).copy_(img)

    sym_patch = img[:sym_len_Hs, :, :]
    inv_idx = torch.arange(sym_patch.size(0) - 1, -1, -1).long()
    sym_patch_inv = sym_patch.index_select(0, inv_idx)
    img_aug.narrow(0, 0, sym_len_Hs).copy_(sym_patch_inv)

    sym_patch = img[-sym_len_He:, :, :]
    inv_idx = torch.arange(sym_patch.size(0) - 1, -1, -1).long()
    sym_patch_inv = sym_patch.index_select(0, inv_idx)
    img_aug.narrow(0, sym_len_Hs + in_H, sym_len_He).copy_(sym_patch_inv)

    out_1 = torch.FloatTensor(out_H, in_W, in_C)
    kernel_width = weights_H.size(1)
    for i in range(out_H):
        idx = int(indices_H[i][0])
        for j in range(out_C):
            out_1[i, :, j] = img_aug[idx:idx + kernel_width, :, j].transpose(0, 1).mv(weights_H[i])

    # process W dimension
    # symmetric copying
    out_1_aug = torch.FloatTensor(out_H, in_W + sym_len_Ws + sym_len_We, in_C)
    out_1_aug.narrow(1, sym_len_Ws, in_W).copy_(out_1)

    sym_patch = out_1[:, :sym_len_Ws, :]
    inv_idx = torch.arange(sym_patch.size(1) - 1, -1, -1).long()
    sym_patch_inv = sym_patch.index_select(1, inv_idx)
    out_1_aug.narrow(1, 0, sym_len_Ws).copy_(sym_patch_inv)

    sym_patch = out_1[:, -sym_len_We:, :]
    inv_idx = torch.arange(sym_patch.size(1) - 1, -1, -1).long()
    sym_patch_inv = sym_patch.index_select(1, inv_idx)
    out_1_aug.narrow(1, sym_len_Ws + in_W, sym_len_We).copy_(sym_patch_inv)

    out_2 = torch.FloatTensor(out_H, out_W, in_C)
    kernel_width = weights_W.size(1)
    for i in range(out_W):
        idx = int(indices_W[i][0])
        for j in range(out_C):
            out_2[:, i, j] = out_1_aug[:, idx:idx + kernel_width, j].mv(weights_W[i])
    if need_squeeze:
        out_2.squeeze_()

    return out_2.numpy()

def calculate_weights_indices(in_length, out_length, scale, kernel, kernel_width, antialiasing):
    if (scale < 1) and (antialiasing):
        # Use a modified kernel to simultaneously interpolate and antialias- larger kernel width
        kernel_width = kernel_width / scale

    # Output-space coordinates
    x = torch.linspace(1, out_length, out_length)

    # Input-space coordinates. Calculate the inverse mapping such that 0.5
    # in output space maps to 0.5 in input space, and 0.5+scale in output
    # space maps to 1.5 in input space.
    u = x / scale + 0.5 * (1 - 1 / scale)

    # What is the left-most pixel that can be involved in the computation?
    left = torch.floor(u - kernel_width / 2)

    # What is the maximum number of pixels that can be involved in the
    # computation?  Note: it's OK to use an extra pixel here; if the
    # corresponding weights are all zero, it will be eliminated at the end
    # of this function.
    P = math.ceil(kernel_width) + 2

    # The indices of the input pixels involved in computing the k-th output
    # pixel are in row k of the indices matrix.
    indices = left.view(out_length, 1).expand(out_length, P) + torch.linspace(0, P - 1, P).view(
        1, P).expand(out_length, P)

    # The weights used to compute the k-th output pixel are in row k of the
    # weights matrix.
    distance_to_center = u.view(out_length, 1).expand(out_length, P) - indices
    # apply cubic kernel
    if (scale < 1) and (antialiasing):
        weights = scale * cubic(distance_to_center * scale)
    else:
        weights = cubic(distance_to_center)
    # Normalize the weights matrix so that each row sums to 1.
    weights_sum = torch.sum(weights, 1).view(out_length, 1)
    weights = weights / weights_sum.expand(out_length, P)

    # If a column in weights is all zero, get rid of it. only consider the first and last column.
    weights_zero_tmp = torch.sum((weights == 0), 0)
    if not math.isclose(weights_zero_tmp[0], 0, rel_tol=1e-6):
        indices = indices.narrow(1, 1, P - 2)
        weights = weights.narrow(1, 1, P - 2)
    if not math.isclose(weights_zero_tmp[-1], 0, rel_tol=1e-6):
        indices = indices.narrow(1, 0, P - 2)
        weights = weights.narrow(1, 0, P - 2)
    weights = weights.contiguous()
    indices = indices.contiguous()
    sym_len_s = -indices.min() + 1
    sym_len_e = indices.max() - in_length
    indices = indices + sym_len_s - 1
    return weights, indices, int(sym_len_s), int(sym_len_e)

def cubic(x):
    absx = torch.abs(x)
    absx2 = absx**2
    absx3 = absx**3
    return (1.5*absx3 - 2.5*absx2 + 1) * ((absx <= 1).type_as(absx)) + \
        (-0.5*absx3 + 2.5*absx2 - 4*absx + 2) * (((absx > 1)*(absx <= 2)).type_as(absx))

# %%
import cv2
import os
from PIL import Image

def gen_LR_deep_blind(image_HR_dir, image_LR_dir, scale=8):
    """
        image_HR_dir: Đường dẫn thư mục chứa bộ data High Resolution
        image_LR_dir: Đường dẫn thư mục để lưu bộ data Low Resolution
        scale: Tỷ lệ sinh ảnh Low Resolution
    """
    if os.path.exists(os.path.join(image_LR_dir)):
        print("Thư mục my_dir đã tồn tại.")
    else:
        os.mkdir(os.path.join(image_LR_dir))
        print("Đã tạo thư mục my_dir.")

    list_image_names = os.listdir(image_HR_dir)  # Lấy dir của toàn bộ tập ảnh
    print(f"total image: {len(list_image_names)}")
    cnt = 0
    for image_name in list_image_names:
        img = imread_uint(os.path.join(image_HR_dir, image_name), 3)
        img = uint2single(img)
        sf = scale
        img_lq, img_hq = degradation_bsrgan(img, sf=sf)
        imsave(single2uint(img_lq), os.path.join(image_LR_dir, image_name))
        cnt += 1
        print("count: ", cnt)
        print(image_name, "LR has been saved! Image size: ", img_lq.shape)

# %%
gen_LR_deep_blind(image_HR_dir = r"/content/datasets/Human_Faces/Human_Faces_train_HR/GTmod8",
                  image_LR_dir = r"/content/datasets/Human_Faces/Human_Faces_train_LR_deep_blind/X4",
                  scale=4)

# %%
gen_LR_deep_blind(image_HR_dir = r"/content/datasets/Human_Faces/Human_Faces_train_HR/GTmod8",
                  image_LR_dir = r"/content/datasets/Human_Faces/Human_Faces_train_LR_deep_blind/X8",
                  scale=8)
# Out:
# Đã tạo thư mục my_dir.
# total image: 2945
# (55, 42, 3)
# (440, 336, 3)
# count:  1
# 0007.png LR has been saved! Image size:  (55, 42, 3)
# <ipython-input-9-485dedf69390>:329: DeprecationWarning: Please use `convolve` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   img = ndimage.filters.convolve(img, np.expand_dims(k, axis=2), mode='mirror')
# (125, 87, 3)
# (1000, 696, 3)
# count:  2
# 0018.png LR has been saved! Image size:  (125, 87, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  3
# 1607.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  4
# 1305.png LR has been saved! Image size:  (75, 75, 3)
# (136, 91, 3)
# (1088, 728, 3)
# count:  5
# 0145.png LR has been saved! Image size:  (136, 91, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  6
# 2133.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  7
# 2244.png LR has been saved! Image size:  (75, 75, 3)
# <ipython-input-9-485dedf69390>:105: DeprecationWarning: `interp2d` is deprecated!
# `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
# For legacy code, nearly bug-for-bug compatible replacements are
# `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
# scattered 2D data.
#
# In new code, for regular grids use `RegularGridInterpolator` instead.
# For scattered data, prefer `LinearNDInterpolator` or
# `CloughTocher2DInterpolator`.
#
# For more details see
# `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   x = interp2d(xv, yv, x)(x1, y1)
# <ipython-input-9-485dedf69390>:105: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   x = interp2d(xv, yv, x)(x1, y1)
# <ipython-input-9-485dedf69390>:458: DeprecationWarning: Please use `convolve` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   img = ndimage.filters.convolve(img, np.expand_dims(k_shifted, axis=2), mode='mirror')
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# (112, 69, 3)
# (896, 552, 3)
# count:  1696
# 1172.png LR has been saved! Image size:  (112, 69, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1697
# 1371.png LR has been saved! Image size:  (75, 75, 3)
# (150, 240, 3)
# (1200, 1920, 3)
# count:  1698
# 0786.png LR has been saved! Image size:  (150, 240, 3)
# (76, 51, 3)
# (608, 408, 3)
# count:  1699
# 0561.png LR has been saved! Image size:  (76, 51, 3)
# (168, 135, 3)
# (1344, 1080, 3)
# count:  1700
# 0514.png LR has been saved! Image size:  (168, 135, 3)
# (65, 65, 3)
# (520, 520, 3)
# count:  1701
# 0064.png LR has been saved! Image size:  (65, 65, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1702
# 1814.png LR has been saved! Image size:  (75, 75, 3)
# (67, 50, 3)
# (536, 400, 3)
# count:  1703
# 0622.png LR has been saved! Image size:  (67, 50, 3)
# (116, 82, 3)
# (928, 656, 3)
# count:  1704
# 0244.png LR has been saved! Image size:  (116, 82, 3)
# (128, 92, 3)
# (1024, 736, 3)
# count:  1705
# 1041.png LR has been saved! Image size:  (128, 92, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1706
# 2079.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1707
# 1710.png LR has been saved! Image size:  (75, 75, 3)
# (118, 82, 3)
# (944, 656, 3)
# count:  1708
# 0623.png LR has been saved! Image size:  (118, 82, 3)
# (75, 56, 3)
# (600, 448, 3)
# count:  1709
# 0234.png LR has been saved! Image size:  (75, 56, 3)
# (137, 92, 3)
# (1096, 736, 3)
# count:  1710
# 0956.png LR has been saved! Image size:  (137, 92, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1711
# 2696.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1712
# 1882.png LR has been saved! Image size:  (75, 75, 3)
# (102, 69, 3)
# (816, 552, 3)
# count:  1713
# 0304.png LR has been saved! Image size:  (102, 69, 3)
# (138, 92, 3)
# (1104, 736, 3)
# count:  1714
# 0075.png LR has been saved! Image size:  (138, 92, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1715
# 2266.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1716
# 2888.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1717
# 2060.png LR has been saved! Image size:  (75, 75, 3)
# (88, 62, 3)
# (704, 496, 3)
# count:  1718
# 0278.png LR has been saved! Image size:  (88, 62, 3)
# (94, 51, 3)
# (752, 408, 3)
# count:  1719
# 1053.png LR has been saved! Image size:  (94, 51, 3)
# (68, 45, 3)
# (544, 360, 3)
# count:  1720
# 1021.png LR has been saved! Image size:  (68, 45, 3)
# (87, 78, 3)
# (696, 624, 3)
# count:  1721
# 1213.png LR has been saved! Image size:  (87, 78, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1722
# 1596.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1723
# 1927.png LR has been saved! Image size:  (75, 75, 3)
# (170, 256, 3)
# (1360, 2048, 3)
# count:  1724
# 1186.png LR has been saved! Image size:  (170, 256, 3)
# (128, 85, 3)
# (1024, 680, 3)
# count:  1725
# 0830.png LR has been saved! Image size:  (128, 85, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1726
# 1959.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1727
# 2129.png LR has been saved! Image size:  (75, 75, 3)
# (93, 59, 3)
# (744, 472, 3)
# count:  1728
# 0411.png LR has been saved! Image size:  (93, 59, 3)
# (125, 79, 3)
# (1000, 632, 3)
# count:  1729
# 0078.png LR has been saved! Image size:  (125, 79, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1730
# 1567.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1731
# 2311.png LR has been saved! Image size:  (75, 75, 3)
# (93, 62, 3)
# (744, 496, 3)
# count:  1732
# 0170.png LR has been saved! Image size:  (93, 62, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1733
# 2062.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1734
# 1739.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1735
# 1601.png LR has been saved! Image size:  (75, 75, 3)
# (162, 119, 3)
# (1296, 952, 3)
# count:  1736
# 1113.png LR has been saved! Image size:  (162, 119, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1737
# 2508.png LR has been saved! Image size:  (75, 75, 3)
# (128, 85, 3)
# (1024, 680, 3)
# count:  1738
# 0832.png LR has been saved! Image size:  (128, 85, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1739
# 1315.png LR has been saved! Image size:  (75, 75, 3)
# (93, 62, 3)
# (744, 496, 3)
# count:  1740
# 0205.png LR has been saved! Image size:  (93, 62, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1741
# 2612.png LR has been saved! Image size:  (75, 75, 3)
# (42, 29, 3)
# (336, 232, 3)
# count:  1742
# 1051.png LR has been saved! Image size:  (42, 29, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1743
# 1992.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1744
# 2438.png LR has been saved! Image size:  (75, 75, 3)
# (193, 125, 3)
# (1544, 1000, 3)
# count:  1745
# 0102.png LR has been saved! Image size:  (193, 125, 3)
# (48, 77, 3)
# (384, 616, 3)
# count:  1746
# 0248.png LR has been saved! Image size:  (48, 77, 3)
# (74, 62, 3)
# (592, 496, 3)
# count:  1747
# 0082.png LR has been saved! Image size:  (74, 62, 3)
# (80, 80, 3)
# (640, 640, 3)
# count:  1748
# 1248.png LR has been saved! Image size:  (80, 80, 3)
# (239, 160, 3)
# (1912, 1280, 3)
# count:  1749
# 0184.png LR has been saved! Image size:  (239, 160, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1750
# 2602.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1751
# 2537.png LR has been saved! Image size:  (75, 75, 3)
# (168, 135, 3)
# (1344, 1080, 3)
# count:  1752
# 0414.png LR has been saved! Image size:  (168, 135, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1753
# 1854.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1754
# 2184.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1755
# 1397.png LR has been saved! Image size:  (75, 75, 3)
# (83, 61, 3)
# (664, 488, 3)
# count:  1756
# 0037.png LR has been saved! Image size:  (83, 61, 3)
# (80, 80, 3)
# (640, 640, 3)
# count:  1757
# 1121.png LR has been saved! Image size:  (80, 80, 3)
# (128, 85, 3)
# (1024, 680, 3)
# count:  1758
# 0173.png LR has been saved! Image size:  (128, 85, 3)
# (298, 198, 3)
# (2384, 1584, 3)
# count:  1759
# 0967.png LR has been saved! Image size:  (298, 198, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1760
# 2282.png LR has been saved! Image size:  (75, 75, 3)
# (960, 640, 3)
# (7680, 5120, 3)
# count:  1761
# 1247.png LR has been saved! Image size:  (960, 640, 3)
# (173, 140, 3)
# (1384, 1120, 3)
# count:  1762
# 0849.png LR has been saved! Image size:  (173, 140, 3)
# (162, 108, 3)
# (1296, 864, 3)
# count:  1763
# 0031.png LR has been saved! Image size:  (162, 108, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1764
# 2785.png LR has been saved! Image size:  (75, 75, 3)
# (110, 93, 3)
# (880, 744, 3)
# count:  1765
# 0139.png LR has been saved! Image size:  (110, 93, 3)
# (43, 29, 3)
# (344, 232, 3)
# count:  1766
# 0390.png LR has been saved! Image size:  (43, 29, 3)
# (113, 75, 3)
# (904, 600, 3)
# count:  1767
# 0132.png LR has been saved! Image size:  (113, 75, 3)
# (385, 684, 3)
# (3080, 5472, 3)
# count:  1768
# 0051.png LR has been saved! Image size:  (385, 684, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1769
# 2092.png LR has been saved! Image size:  (75, 75, 3)
# (138, 92, 3)
# (1104, 736, 3)
# count:  1770
# 0556.png LR has been saved! Image size:  (138, 92, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1771
# 1655.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1772
# 1615.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1773
# 2491.png LR has been saved! Image size:  (75, 75, 3)
# (96, 128, 3)
# (768, 1024, 3)
# count:  1774
# 0903.png LR has been saved! Image size:  (96, 128, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1775
# 2130.png LR has been saved! Image size:  (75, 75, 3)
# (187, 144, 3)
# (1496, 1152, 3)
# count:  1776
# 0382.png LR has been saved! Image size:  (187, 144, 3)
# (93, 62, 3)
# (744, 496, 3)
# count:  1777
# 0001.png LR has been saved! Image size:  (93, 62, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1778
# 1777.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1779
# 1421.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1780
# 2322.png LR has been saved! Image size:  (75, 75, 3)
# (110, 83, 3)
# (880, 664, 3)
# count:  1781
# 0877.png LR has been saved! Image size:  (110, 83, 3)
# (128, 97, 3)
# (1024, 776, 3)
# count:  1782
# 0515.png LR has been saved! Image size:  (128, 97, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1783
# 1383.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1784
# 2620.png LR has been saved! Image size:  (75, 75, 3)
# (168, 135, 3)
# (1344, 1080, 3)
# count:  1785
# 0154.png LR has been saved! Image size:  (168, 135, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1786
# 2570.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1787
# 1343.png LR has been saved! Image size:  (75, 75, 3)
# (160, 106, 3)
# (1280, 848, 3)
# count:  1788
# 0422.png LR has been saved! Image size:  (160, 106, 3)
# (92, 70, 3)
# (736, 560, 3)
# count:  1789
# 0073.png LR has been saved! Image size:  (92, 70, 3)
# (150, 100, 3)
# (1200, 800, 3)
# count:  1790
# 0486.png LR has been saved! Image size:  (150, 100, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1791
# 1281.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1792
# 2440.png LR has been saved! Image size:  (75, 75, 3)
# (88, 75, 3)
# (704, 600, 3)
# count:  1793
# 0212.png LR has been saved! Image size:  (88, 75, 3)
# (161, 141, 3)
# (1288, 1128, 3)
# count:  1794
# 1189.png LR has been saved! Image size:  (161, 141, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1795
# 1318.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1796
# 1976.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1797
# 2068.png LR has been saved! Image size:  (75, 75, 3)
# (132, 107, 3)
# (1056, 856, 3)
# count:  1798
# 1125.png LR has been saved! Image size:  (132, 107, 3)
# (128, 91, 3)
# (1024, 728, 3)
# count:  1799
# 1112.png LR has been saved! Image size:  (128, 91, 3)
# (500, 585, 3)
# (4000, 4680, 3)
# count:  1800
# 0106.png LR has been saved! Image size:  (500, 585, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1801
# 1681.png LR has been saved! Image size:  (75, 75, 3)
# (219, 160, 3)
# (1752, 1280, 3)
# count:  1802
# 0047.png LR has been saved! Image size:  (219, 160, 3)
# (87, 58, 3)
# (696, 464, 3)
# count:  1803
# 0900.png LR has been saved! Image size:  (87, 58, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1804
# 2494.png LR has been saved! Image size:  (75, 75, 3)
# (93, 62, 3)
# (744, 496, 3)
# count:  1805
# 0213.png LR has been saved! Image size:  (93, 62, 3)
# (552, 414, 3)
# (4416, 3312, 3)
# count:  1806
# 0141.png LR has been saved! Image size:  (552, 414, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1807
# 1812.png LR has been saved! Image size:  (75, 75, 3)
# (128, 85, 3)
# (1024, 680, 3)
# count:  1808
# 0301.png LR has been saved! Image size:  (128, 85, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1809
# 1452.png LR has been saved! Image size:  (75, 75, 3)
# (76, 76, 3)
# (608, 608, 3)
# count:  1810
# 0166.png LR has been saved! Image size:  (76, 76, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1811
# 2174.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1812
# 2750.png LR has been saved! Image size:  (75, 75, 3)
# (118, 92, 3)
# (944, 736, 3)
# count:  1813
# 0951.png LR has been saved! Image size:  (118, 92, 3)
# (127, 85, 3)
# (1016, 680, 3)
# count:  1814
# 1168.png LR has been saved! Image size:  (127, 85, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1815
# 1407.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1816
# 1885.png LR has been saved! Image size:  (75, 75, 3)
# (114, 92, 3)
# (912, 736, 3)
# count:  1817
# 0879.png LR has been saved! Image size:  (114, 92, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1818
# 2334.png LR has been saved! Image size:  (75, 75, 3)
# (225, 150, 3)
# (1800, 1200, 3)
# count:  1819
# 1246.png LR has been saved! Image size:  (225, 150, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1820
# 2208.png LR has been saved! Image size:  (75, 75, 3)
# (44, 29, 3)
# (352, 232, 3)
# count:  1821
# 1162.png LR has been saved! Image size:  (44, 29, 3)
# (98, 67, 3)
# (784, 536, 3)
# count:  1822
# 1025.png LR has been saved! Image size:  (98, 67, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1823
# 2220.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1824
# 2857.png LR has been saved! Image size:  (75, 75, 3)
# (168, 112, 3)
# (1344, 896, 3)
# count:  1825
# 0539.png LR has been saved! Image size:  (168, 112, 3)
# (79, 62, 3)
# (632, 496, 3)
# count:  1826
# 0957.png LR has been saved! Image size:  (79, 62, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1827
# 1768.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1828
# 1951.png LR has been saved! Image size:  (75, 75, 3)
# (60, 106, 3)
# (480, 848, 3)
# count:  1829
# 1216.png LR has been saved! Image size:  (60, 106, 3)
# (281, 187, 3)
# (2248, 1496, 3)
# count:  1830
# 0535.png LR has been saved! Image size:  (281, 187, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1831
# 2214.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1832
# 2007.png LR has been saved! Image size:  (75, 75, 3)
# (361, 289, 3)
# (2888, 2312, 3)
# count:  1833
# 0186.png LR has been saved! Image size:  (361, 289, 3)
# (150, 200, 3)
# (1200, 1600, 3)
# count:  1834
# 0748.png LR has been saved! Image size:  (150, 200, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1835
# 1474.png LR has been saved! Image size:  (75, 75, 3)
# (138, 92, 3)
# (1104, 736, 3)
# count:  1836
# 0169.png LR has been saved! Image size:  (138, 92, 3)
# (150, 240, 3)
# (1200, 1920, 3)
# count:  1837
# 0691.png LR has been saved! Image size:  (150, 240, 3)
# (128, 82, 3)
# (1024, 656, 3)
# count:  1838
# 1037.png LR has been saved! Image size:  (128, 82, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1839
# 2451.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1840
# 2383.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1841
# 2431.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1842
# 2048.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1843
# 2332.png LR has been saved! Image size:  (75, 75, 3)
# (920, 614, 3)
# (7360, 4912, 3)
# count:  1844
# 1211.png LR has been saved! Image size:  (920, 614, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1845
# 1536.png LR has been saved! Image size:  (75, 75, 3)
# (198, 125, 3)
# (1584, 1000, 3)
# count:  1846
# 0920.png LR has been saved! Image size:  (198, 125, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1847
# 1441.png LR has been saved! Image size:  (75, 75, 3)
# (114, 92, 3)
# (912, 736, 3)
# count:  1848
# 1174.png LR has been saved! Image size:  (114, 92, 3)
# (133, 100, 3)
# (1064, 800, 3)
# count:  1849
# 2937.png LR has been saved! Image size:  (133, 100, 3)
# (67, 62, 3)
# (536, 496, 3)
# count:  1850
# 0638.png LR has been saved! Image size:  (67, 62, 3)
# (166, 121, 3)
# (1328, 968, 3)
# count:  1851
# 1263.png LR has been saved! Image size:  (166, 121, 3)
# (128, 102, 3)
# (1024, 816, 3)
# count:  1852
# 0785.png LR has been saved! Image size:  (128, 102, 3)
# (87, 55, 3)
# (696, 440, 3)
# count:  1853
# 0256.png LR has been saved! Image size:  (87, 55, 3)
# (522, 341, 3)
# (4176, 2728, 3)
# count:  1854
# 1193.png LR has been saved! Image size:  (522, 341, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1855
# 2193.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1856
# 2367.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1857
# 2157.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1858
# 2923.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1859
# 1560.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1860
# 1810.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1861
# 2670.png LR has been saved! Image size:  (75, 75, 3)
# (118, 79, 3)
# (944, 632, 3)
# count:  1862
# 0424.png LR has been saved! Image size:  (118, 79, 3)
# (204, 150, 3)
# (1632, 1200, 3)
# count:  1863
# 0206.png LR has been saved! Image size:  (204, 150, 3)
# (62, 46, 3)
# (496, 368, 3)
# count:  1864
# 0525.png LR has been saved! Image size:  (62, 46, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1865
# 2614.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1866
# 2277.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1867
# 1670.png LR has been saved! Image size:  (75, 75, 3)
# (90, 160, 3)
# (720, 1280, 3)
# count:  1868
# 1253.png LR has been saved! Image size:  (90, 160, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1869
# 1564.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1870
# 2418.png LR has been saved! Image size:  (75, 75, 3)
# (93, 62, 3)
# (744, 496, 3)
# count:  1871
# 0519.png LR has been saved! Image size:  (93, 62, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1872
# 1950.png LR has been saved! Image size:  (75, 75, 3)
# (138, 92, 3)
# (1104, 736, 3)
# count:  1873
# 0488.png LR has been saved! Image size:  (138, 92, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1874
# 1594.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1875
# 1527.png LR has been saved! Image size:  (75, 75, 3)
# (123, 87, 3)
# (984, 696, 3)
# count:  1876
# 0924.png LR has been saved! Image size:  (123, 87, 3)
# (120, 96, 3)
# (960, 768, 3)
# count:  1877
# 0336.png LR has been saved! Image size:  (120, 96, 3)
# (375, 250, 3)
# (3000, 2000, 3)
# count:  1878
# 0908.png LR has been saved! Image size:  (375, 250, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1879
# 2759.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1880
# 1802.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1881
# 2756.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1882
# 1881.png LR has been saved! Image size:  (75, 75, 3)
# (75, 50, 3)
# (600, 400, 3)
# count:  1883
# 0272.png LR has been saved! Image size:  (75, 50, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1884
# 1457.png LR has been saved! Image size:  (75, 75, 3)
# (75, 50, 3)
# (600, 400, 3)
# count:  1885
# 0988.png LR has been saved! Image size:  (75, 50, 3)
# (101, 87, 3)
# (808, 696, 3)
# count:  1886
# 1164.png LR has been saved! Image size:  (101, 87, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1887
# 2543.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1888
# 2290.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1889
# 2023.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1890
# 2758.png LR has been saved! Image size:  (75, 75, 3)
# (318, 216, 3)
# (2544, 1728, 3)
# count:  1891
# 1126.png LR has been saved! Image size:  (318, 216, 3)
# (57, 87, 3)
# (456, 696, 3)
# count:  1892
# 0604.png LR has been saved! Image size:  (57, 87, 3)
# (190, 130, 3)
# (1520, 1040, 3)
# count:  1893
# 1098.png LR has been saved! Image size:  (190, 130, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1894
# 2907.png LR has been saved! Image size:  (75, 75, 3)
# (74, 50, 3)
# (592, 400, 3)
# count:  1895
# 0662.png LR has been saved! Image size:  (74, 50, 3)
# (180, 240, 3)
# (1440, 1920, 3)
# count:  1896
# 1207.png LR has been saved! Image size:  (180, 240, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1897
# 1568.png LR has been saved! Image size:  (75, 75, 3)
# (122, 92, 3)
# (976, 736, 3)
# count:  1898
# 1071.png LR has been saved! Image size:  (122, 92, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1899
# 2654.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1900
# 1873.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1901
# 2243.png LR has been saved! Image size:  (75, 75, 3)
# (551, 234, 3)
# (4408, 1872, 3)
# count:  1902
# 1195.png LR has been saved! Image size:  (551, 234, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1903
# 1925.png LR has been saved! Image size:  (75, 75, 3)
# (53, 80, 3)
# (424, 640, 3)
# count:  1904
# 1068.png LR has been saved! Image size:  (53, 80, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1905
# 1890.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1906
# 2164.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1907
# 1680.png LR has been saved! Image size:  (75, 75, 3)
# (87, 62, 3)
# (696, 496, 3)
# count:  1908
# 0545.png LR has been saved! Image size:  (87, 62, 3)
# (288, 432, 3)
# (2304, 3456, 3)
# count:  1909
# 0739.png LR has been saved! Image size:  (288, 432, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1910
# 1780.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1911
# 2646.png LR has been saved! Image size:  (75, 75, 3)
# (100, 88, 3)
# (800, 704, 3)
# count:  1912
# 0450.png LR has been saved! Image size:  (100, 88, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1913
# 1555.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1914
# 1414.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1915
# 1863.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1916
# 2650.png LR has been saved! Image size:  (75, 75, 3)
# (138, 92, 3)
# (1104, 736, 3)
# count:  1917
# 1165.png LR has been saved! Image size:  (138, 92, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1918
# 1793.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1919
# 2910.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1920
# 2415.png LR has been saved! Image size:  (75, 75, 3)
# (128, 85, 3)
# (1024, 680, 3)
# count:  1921
# 0048.png LR has been saved! Image size:  (128, 85, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1922
# 1291.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1923
# 2703.png LR has been saved! Image size:  (75, 75, 3)
# (122, 92, 3)
# (976, 736, 3)
# count:  1924
# 0777.png LR has been saved! Image size:  (122, 92, 3)
# (93, 62, 3)
# (744, 496, 3)
# count:  1925
# 0036.png LR has been saved! Image size:  (93, 62, 3)
# (112, 112, 3)
# (896, 896, 3)
# count:  1926
# 1072.png LR has been saved! Image size:  (112, 112, 3)
# (138, 92, 3)
# (1104, 736, 3)
# count:  1927
# 1188.png LR has been saved! Image size:  (138, 92, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1928
# 2885.png LR has been saved! Image size:  (75, 75, 3)
# (95, 80, 3)
# (760, 640, 3)
# count:  1929
# 0521.png LR has been saved! Image size:  (95, 80, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1930
# 1381.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1931
# 2256.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1932
# 1442.png LR has been saved! Image size:  (75, 75, 3)
# (114, 92, 3)
# (912, 736, 3)
# count:  1933
# 0689.png LR has been saved! Image size:  (114, 92, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1934
# 2551.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1935
# 1304.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1936
# 1789.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1937
# 2629.png LR has been saved! Image size:  (75, 75, 3)
# (384, 256, 3)
# (3072, 2048, 3)
# count:  1938
# 0669.png LR has been saved! Image size:  (384, 256, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1939
# 1293.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1940
# 1719.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1941
# 1997.png LR has been saved! Image size:  (75, 75, 3)
# (120, 90, 3)
# (960, 720, 3)
# count:  1942
# 0432.png LR has been saved! Image size:  (120, 90, 3)
# (76, 75, 3)
# (608, 600, 3)
# count:  1943
# 0280.png LR has been saved! Image size:  (76, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1944
# 2876.png LR has been saved! Image size:  (75, 75, 3)
# (138, 92, 3)
# (1104, 736, 3)
# count:  1945
# 0791.png LR has been saved! Image size:  (138, 92, 3)
# (166, 92, 3)
# (1328, 736, 3)
# count:  1946
# 0340.png LR has been saved! Image size:  (166, 92, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1947
# 1646.png LR has been saved! Image size:  (75, 75, 3)
# (138, 92, 3)
# (1104, 736, 3)
# count:  1948
# 0726.png LR has been saved! Image size:  (138, 92, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1949
# 2159.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1950
# 2076.png LR has been saved! Image size:  (75, 75, 3)
# (93, 62, 3)
# (744, 496, 3)
# count:  1951
# 0377.png LR has been saved! Image size:  (93, 62, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1952
# 2848.png LR has been saved! Image size:  (75, 75, 3)
# (534, 356, 3)
# (4272, 2848, 3)
# count:  1953
# 0930.png LR has been saved! Image size:  (534, 356, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1954
# 2804.png LR has been saved! Image size:  (75, 75, 3)
# (90, 135, 3)
# (720, 1080, 3)
# count:  1955
# 1156.png LR has been saved! Image size:  (90, 135, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1956
# 2316.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1957
# 2597.png LR has been saved! Image size:  (75, 75, 3)
# (128, 85, 3)
# (1024, 680, 3)
# count:  1958
# 0158.png LR has been saved! Image size:  (128, 85, 3)
# (250, 250, 3)
# (2000, 2000, 3)
# count:  1959
# 2021.png LR has been saved! Image size:  (250, 250, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1960
# 2801.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1961
# 2897.png LR has been saved! Image size:  (75, 75, 3)
# (80, 80, 3)
# (640, 640, 3)
# count:  1962
# 0271.png LR has been saved! Image size:  (80, 80, 3)
# (138, 92, 3)
# (1104, 736, 3)
# count:  1963
# 0696.png LR has been saved! Image size:  (138, 92, 3)
# (47, 29, 3)
# (376, 232, 3)
# count:  1964
# 0123.png LR has been saved! Image size:  (47, 29, 3)
# (44, 29, 3)
# (352, 232, 3)
# count:  1965
# 0548.png LR has been saved! Image size:  (44, 29, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1966
# 1396.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1967
# 2519.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1968
# 1537.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1969
# 1808.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1970
# 2635.png LR has been saved! Image size:  (75, 75, 3)
# (90, 70, 3)
# (720, 560, 3)
# count:  1971
# 0898.png LR has been saved! Image size:  (90, 70, 3)
# (562, 375, 3)
# (4496, 3000, 3)
# count:  1972
# 2935.png LR has been saved! Image size:  (562, 375, 3)
# (90, 67, 3)
# (720, 536, 3)
# count:  1973
# 1222.png LR has been saved! Image size:  (90, 67, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1974
# 1348.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1975
# 1590.png LR has been saved! Image size:  (75, 75, 3)
# (192, 128, 3)
# (1536, 1024, 3)
# count:  1976
# 1138.png LR has been saved! Image size:  (192, 128, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1977
# 1813.png LR has been saved! Image size:  (75, 75, 3)
# (410, 410, 3)
# (3280, 3280, 3)
# count:  1978
# 0888.png LR has been saved! Image size:  (410, 410, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1979
# 2058.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1980
# 1497.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1981
# 2733.png LR has been saved! Image size:  (75, 75, 3)
# (93, 62, 3)
# (744, 496, 3)
# count:  1982
# 0348.png LR has been saved! Image size:  (93, 62, 3)
# (60, 40, 3)
# (480, 320, 3)
# count:  1983
# 0217.png LR has been saved! Image size:  (60, 40, 3)
# (93, 62, 3)
# (744, 496, 3)
# count:  1984
# 0527.png LR has been saved! Image size:  (93, 62, 3)
# (138, 92, 3)
# (1104, 736, 3)
# count:  1985
# 0655.png LR has been saved! Image size:  (138, 92, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1986
# 1368.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1987
# 1967.png LR has been saved! Image size:  (75, 75, 3)
# (128, 96, 3)
# (1024, 768, 3)
# count:  1988
# 0162.png LR has been saved! Image size:  (128, 96, 3)
# (128, 93, 3)
# (1024, 744, 3)
# count:  1989
# 0143.png LR has been saved! Image size:  (128, 93, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1990
# 2588.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1991
# 2326.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1992
# 2052.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1993
# 1412.png LR has been saved! Image size:  (75, 75, 3)
# (113, 68, 3)
# (904, 544, 3)
# count:  1994
# 0631.png LR has been saved! Image size:  (113, 68, 3)
# (94, 68, 3)
# (752, 544, 3)
# count:  1995
# 0553.png LR has been saved! Image size:  (94, 68, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1996
# 1382.png LR has been saved! Image size:  (75, 75, 3)
# (124, 83, 3)
# (992, 664, 3)
# count:  1997
# 0825.png LR has been saved! Image size:  (124, 83, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1998
# 2828.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  1999
# 2065.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2000
# 1611.png LR has been saved! Image size:  (75, 75, 3)
# (507, 337, 3)
# (4056, 2696, 3)
# count:  2001
# 0363.png LR has been saved! Image size:  (507, 337, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2002
# 1805.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2003
# 2441.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2004
# 1393.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2005
# 2298.png LR has been saved! Image size:  (75, 75, 3)
# (92, 74, 3)
# (736, 592, 3)
# count:  2006
# 1060.png LR has been saved! Image size:  (92, 74, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2007
# 2917.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2008
# 2572.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2009
# 2798.png LR has been saved! Image size:  (75, 75, 3)
# (104, 78, 3)
# (832, 624, 3)
# count:  2010
# 0867.png LR has been saved! Image size:  (104, 78, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2011
# 1779.png LR has been saved! Image size:  (75, 75, 3)
# (536, 356, 3)
# (4288, 2848, 3)
# count:  2012
# 1267.png LR has been saved! Image size:  (536, 356, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2013
# 2593.png LR has been saved! Image size:  (75, 75, 3)
# (138, 92, 3)
# (1104, 736, 3)
# count:  2014
# 0442.png LR has been saved! Image size:  (138, 92, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2015
# 2091.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2016
# 2020.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2017
# 2067.png LR has been saved! Image size:  (75, 75, 3)
# (708, 472, 3)
# (5664, 3776, 3)
# count:  2018
# 0963.png LR has been saved! Image size:  (708, 472, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2019
# 2498.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2020
# 1390.png LR has been saved! Image size:  (75, 75, 3)
# (137, 92, 3)
# (1096, 736, 3)
# count:  2021
# 0952.png LR has been saved! Image size:  (137, 92, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2022
# 1295.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2023
# 1298.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2024
# 2531.png LR has been saved! Image size:  (75, 75, 3)
# (50, 33, 3)
# (400, 264, 3)
# count:  2025
# 0975.png LR has been saved! Image size:  (50, 33, 3)
# (141, 100, 3)
# (1128, 800, 3)
# count:  2026
# 0707.png LR has been saved! Image size:  (141, 100, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2027
# 1647.png LR has been saved! Image size:  (75, 75, 3)
# (129, 92, 3)
# (1032, 736, 3)
# count:  2028
# 0982.png LR has been saved! Image size:  (129, 92, 3)
# (220, 150, 3)
# (1760, 1200, 3)
# count:  2029
# 0793.png LR has been saved! Image size:  (220, 150, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2030
# 2439.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2031
# 2484.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2032
# 1624.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2033
# 2410.png LR has been saved! Image size:  (75, 75, 3)
# (200, 133, 3)
# (1600, 1064, 3)
# count:  2034
# 1116.png LR has been saved! Image size:  (200, 133, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2035
# 2715.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2036
# 1765.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2037
# 2310.png LR has been saved! Image size:  (75, 75, 3)
# (100, 100, 3)
# (800, 800, 3)
# count:  2038
# 0365.png LR has been saved! Image size:  (100, 100, 3)
# (71, 62, 3)
# (568, 496, 3)
# count:  2039
# 2945.png LR has been saved! Image size:  (71, 62, 3)
# (61, 92, 3)
# (488, 736, 3)
# count:  2040
# 0891.png LR has been saved! Image size:  (61, 92, 3)
# (46, 31, 3)
# (368, 248, 3)
# count:  2041
# 0258.png LR has been saved! Image size:  (46, 31, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2042
# 2160.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2043
# 2916.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2044
# 2568.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2045
# 1707.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2046
# 1829.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2047
# 1754.png LR has been saved! Image size:  (75, 75, 3)
# (128, 160, 3)
# (1024, 1280, 3)
# count:  2048
# 0763.png LR has been saved! Image size:  (128, 160, 3)
# (56, 37, 3)
# (448, 296, 3)
# count:  2049
# 0747.png LR has been saved! Image size:  (56, 37, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2050
# 2080.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2051
# 2868.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2052
# 1849.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2053
# 2625.png LR has been saved! Image size:  (75, 75, 3)
# (62, 42, 3)
# (496, 336, 3)
# count:  2054
# 0345.png LR has been saved! Image size:  (62, 42, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2055
# 2765.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2056
# 2233.png LR has been saved! Image size:  (75, 75, 3)
# (225, 150, 3)
# (1800, 1200, 3)
# count:  2057
# 0436.png LR has been saved! Image size:  (225, 150, 3)
# (138, 92, 3)
# (1104, 736, 3)
# count:  2058
# 1043.png LR has been saved! Image size:  (138, 92, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2059
# 1384.png LR has been saved! Image size:  (75, 75, 3)
# (50, 40, 3)
# (400, 320, 3)
# count:  2060
# 0125.png LR has been saved! Image size:  (50, 40, 3)
# (214, 155, 3)
# (1712, 1240, 3)
# count:  2061
# 0602.png LR has been saved! Image size:  (214, 155, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2062
# 2878.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2063
# 1460.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2064
# 1551.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2065
# 2378.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2066
# 2855.png LR has been saved! Image size:  (75, 75, 3)
# (162, 119, 3)
# (1296, 952, 3)
# count:  2067
# 0237.png LR has been saved! Image size:  (162, 119, 3)
# (62, 55, 3)
# (496, 440, 3)
# count:  2068
# 0269.png LR has been saved! Image size:  (62, 55, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2069
# 2769.png LR has been saved! Image size:  (75, 75, 3)
# (182, 120, 3)
# (1456, 960, 3)
# count:  2070
# 0183.png LR has been saved! Image size:  (182, 120, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2071
# 2380.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2072
# 1351.png LR has been saved! Image size:  (75, 75, 3)
# (60, 40, 3)
# (480, 320, 3)
# count:  2073
# 0444.png LR has been saved! Image size:  (60, 40, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2074
# 1420.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2075
# 1480.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2076
# 1869.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2077
# 2364.png LR has been saved! Image size:  (75, 75, 3)
# (200, 200, 3)
# (1600, 1600, 3)
# count:  2078
# 0074.png LR has been saved! Image size:  (200, 200, 3)
# (61, 64, 3)
# (488, 512, 3)
# count:  2079
# 0504.png LR has been saved! Image size:  (61, 64, 3)
# (137, 92, 3)
# (1096, 736, 3)
# count:  2080
# 0374.png LR has been saved! Image size:  (137, 92, 3)
# (93, 62, 3)
# (744, 496, 3)
# count:  2081
# 0468.png LR has been saved! Image size:  (93, 62, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2082
# 1565.png LR has been saved! Image size:  (75, 75, 3)
# (100, 75, 3)
# (800, 600, 3)
# count:  2083
# 0421.png LR has been saved! Image size:  (100, 75, 3)
# (168, 135, 3)
# (1344, 1080, 3)
# count:  2084
# 0157.png LR has been saved! Image size:  (168, 135, 3)
# (60, 42, 3)
# (480, 336, 3)
# count:  2085
# 0396.png LR has been saved! Image size:  (60, 42, 3)
# (225, 360, 3)
# (1800, 2880, 3)
# count:  2086
# 0331.png LR has been saved! Image size:  (225, 360, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2087
# 2787.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2088
# 2288.png LR has been saved! Image size:  (75, 75, 3)
# (162, 119, 3)
# (1296, 952, 3)
# count:  2089
# 0182.png LR has been saved! Image size:  (162, 119, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2090
# 1300.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2091
# 1806.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2092
# 1819.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2093
# 2840.png LR has been saved! Image size:  (75, 75, 3)
# (128, 85, 3)
# (1024, 680, 3)
# count:  2094
# 1103.png LR has been saved! Image size:  (128, 85, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2095
# 2725.png LR has been saved! Image size:  (75, 75, 3)
# (450, 300, 3)
# (3600, 2400, 3)
# count:  2096
# 0343.png LR has been saved! Image size:  (450, 300, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2097
# 2680.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2098
# 1556.png LR has been saved! Image size:  (75, 75, 3)
# (93, 62, 3)
# (744, 496, 3)
# count:  2099
# 0211.png LR has been saved! Image size:  (93, 62, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2100
# 1795.png LR has been saved! Image size:  (75, 75, 3)
# (196, 160, 3)
# (1568, 1280, 3)
# count:  2101
# 0660.png LR has been saved! Image size:  (196, 160, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2102
# 1331.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2103
# 2542.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2104
# 1410.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2105
# 1437.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2106
# 2351.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2107
# 2119.png LR has been saved! Image size:  (75, 75, 3)
# (449, 323, 3)
# (3592, 2584, 3)
# count:  2108
# 0864.png LR has been saved! Image size:  (449, 323, 3)
# (200, 125, 3)
# (1600, 1000, 3)
# count:  2109
# 0765.png LR has been saved! Image size:  (200, 125, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2110
# 1665.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2111
# 2482.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2112
# 1449.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2113
# 1316.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2114
# 1328.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2115
# 1971.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2116
# 1794.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2117
# 2911.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2118
# 2912.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2119
# 2345.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2120
# 2199.png LR has been saved! Image size:  (75, 75, 3)
# (125, 250, 3)
# (1000, 2000, 3)
# count:  2121
# 0985.png LR has been saved! Image size:  (125, 250, 3)
# (157, 157, 3)
# (1256, 1256, 3)
# count:  2122
# 0528.png LR has been saved! Image size:  (157, 157, 3)
# (112, 84, 3)
# (896, 672, 3)
# count:  2123
# 0142.png LR has been saved! Image size:  (112, 84, 3)
# (200, 142, 3)
# (1600, 1136, 3)
# count:  2124
# 0531.png LR has been saved! Image size:  (200, 142, 3)
# (143, 92, 3)
# (1144, 736, 3)
# count:  2125
# 1127.png LR has been saved! Image size:  (143, 92, 3)
# (80, 53, 3)
# (640, 424, 3)
# count:  2126
# 0730.png LR has been saved! Image size:  (80, 53, 3)
# (112, 75, 3)
# (896, 600, 3)
# count:  2127
# 0207.png LR has been saved! Image size:  (112, 75, 3)
# (93, 62, 3)
# (744, 496, 3)
# count:  2128
# 0072.png LR has been saved! Image size:  (93, 62, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2129
# 1570.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2130
# 1575.png LR has been saved! Image size:  (75, 75, 3)
# (128, 92, 3)
# (1024, 736, 3)
# count:  2131
# 1152.png LR has been saved! Image size:  (128, 92, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2132
# 2008.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2133
# 1337.png LR has been saved! Image size:  (75, 75, 3)
# (648, 432, 3)
# (5184, 3456, 3)
# count:  2134
# 0661.png LR has been saved! Image size:  (648, 432, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2135
# 1380.png LR has been saved! Image size:  (75, 75, 3)
# (93, 62, 3)
# (744, 496, 3)
# count:  2136
# 0215.png LR has been saved! Image size:  (93, 62, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2137
# 2038.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2138
# 2449.png LR has been saved! Image size:  (75, 75, 3)
# (183, 122, 3)
# (1464, 976, 3)
# count:  2139
# 1033.png LR has been saved! Image size:  (183, 122, 3)
# (140, 93, 3)
# (1120, 744, 3)
# count:  2140
# 0944.png LR has been saved! Image size:  (140, 93, 3)
# (29, 29, 3)
# (232, 232, 3)
# count:  2141
# 0651.png LR has been saved! Image size:  (29, 29, 3)
# (81, 62, 3)
# (648, 496, 3)
# count:  2142
# 0973.png LR has been saved! Image size:  (81, 62, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2143
# 2830.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2144
# 2894.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2145
# 1492.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2146
# 1635.png LR has been saved! Image size:  (75, 75, 3)
# (64, 47, 3)
# (512, 376, 3)
# count:  2147
# 0635.png LR has been saved! Image size:  (64, 47, 3)
# (304, 140, 3)
# (2432, 1120, 3)
# count:  2148
# 0709.png LR has been saved! Image size:  (304, 140, 3)
# (90, 59, 3)
# (720, 472, 3)
# count:  2149
# 1180.png LR has been saved! Image size:  (90, 59, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2150
# 2180.png LR has been saved! Image size:  (75, 75, 3)
# (46, 75, 3)
# (368, 600, 3)
# count:  2151
# 0446.png LR has been saved! Image size:  (46, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2152
# 2212.png LR has been saved! Image size:  (75, 75, 3)
# (100, 66, 3)
# (800, 528, 3)
# count:  2153
# 0053.png LR has been saved! Image size:  (100, 66, 3)
# (164, 100, 3)
# (1312, 800, 3)
# count:  2154
# 0389.png LR has been saved! Image size:  (164, 100, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2155
# 2377.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2156
# 2643.png LR has been saved! Image size:  (75, 75, 3)
# (127, 84, 3)
# (1016, 672, 3)
# count:  2157
# 0608.png LR has been saved! Image size:  (127, 84, 3)
# (450, 300, 3)
# (3600, 2400, 3)
# count:  2158
# 0932.png LR has been saved! Image size:  (450, 300, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2159
# 1684.png LR has been saved! Image size:  (75, 75, 3)
# (150, 100, 3)
# (1200, 800, 3)
# count:  2160
# 0015.png LR has been saved! Image size:  (150, 100, 3)
# (44, 43, 3)
# (352, 344, 3)
# count:  2161
# 1157.png LR has been saved! Image size:  (44, 43, 3)
# (128, 128, 3)
# (1024, 1024, 3)
# count:  2162
# 0274.png LR has been saved! Image size:  (128, 128, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2163
# 1387.png LR has been saved! Image size:  (75, 75, 3)
# (545, 426, 3)
# (4360, 3408, 3)
# count:  2164
# 0936.png LR has been saved! Image size:  (545, 426, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2165
# 1454.png LR has been saved! Image size:  (75, 75, 3)
# (125, 83, 3)
# (1000, 664, 3)
# count:  2166
# 0341.png LR has been saved! Image size:  (125, 83, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2167
# 2102.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2168
# 2632.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2169
# 1867.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2170
# 2454.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2171
# 2688.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2172
# 2249.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2173
# 1945.png LR has been saved! Image size:  (75, 75, 3)
# (241, 175, 3)
# (1928, 1400, 3)
# count:  2174
# 0744.png LR has been saved! Image size:  (241, 175, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2175
# 1790.png LR has been saved! Image size:  (75, 75, 3)
# (90, 55, 3)
# (720, 440, 3)
# count:  2176
# 0323.png LR has been saved! Image size:  (90, 55, 3)
# (96, 66, 3)
# (768, 528, 3)
# count:  2177
# 0756.png LR has been saved! Image size:  (96, 66, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2178
# 2501.png LR has been saved! Image size:  (75, 75, 3)
# (96, 128, 3)
# (768, 1024, 3)
# count:  2179
# 0171.png LR has been saved! Image size:  (96, 128, 3)
# (175, 125, 3)
# (1400, 1000, 3)
# count:  2180
# 0362.png LR has been saved! Image size:  (175, 125, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2181
# 2497.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2182
# 1333.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2183
# ...
# (75, 75, 3)
# (600, 600, 3)
# count:  2775
# 1509.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2776
# 2736.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2777
# 2642.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2778
# 2809.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2779
# 2514.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2780
# 1290.png LR has been saved! Image size:  (75, 75, 3)
# (272, 174, 3)
# (2176, 1392, 3)
# count:  2781
# 0111.png LR has been saved! Image size:  (272, 174, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2782
# 2761.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2783
# 1334.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2784
# 1784.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2785
# 1319.png LR has been saved! Image size:  (75, 75, 3)
# (112, 77, 3)
# (896, 616, 3)
# count:  2786
# 0883.png LR has been saved! Image size:  (112, 77, 3)
# (80, 53, 3)
# (640, 424, 3)
# count:  2787
# 1050.png LR has been saved! Image size:  (80, 53, 3)
# (80, 53, 3)
# (640, 424, 3)
# count:  2788
# 0579.png LR has been saved! Image size:  (80, 53, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2789
# 2247.png LR has been saved! Image size:  (75, 75, 3)
# (93, 62, 3)
# (744, 496, 3)
# count:  2790
# 0463.png LR has been saved! Image size:  (93, 62, 3)
# (90, 60, 3)
# (720, 480, 3)
# count:  2791
# 0559.png LR has been saved! Image size:  (90, 60, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2792
# 2296.png LR has been saved! Image size:  (75, 75, 3)
# (82, 70, 3)
# (656, 560, 3)
# count:  2793
# 0228.png LR has been saved! Image size:  (82, 70, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2794
# 1973.png LR has been saved! Image size:  (75, 75, 3)
# (103, 68, 3)
# (824, 544, 3)
# count:  2795
# 0104.png LR has been saved! Image size:  (103, 68, 3)
# (156, 112, 3)
# (1248, 896, 3)
# count:  2796
# 0209.png LR has been saved! Image size:  (156, 112, 3)
# (168, 135, 3)
# (1344, 1080, 3)
# count:  2797
# 1012.png LR has been saved! Image size:  (168, 135, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2798
# 1428.png LR has been saved! Image size:  (75, 75, 3)
# (187, 125, 3)
# (1496, 1000, 3)
# count:  2799
# 0523.png LR has been saved! Image size:  (187, 125, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2800
# 1736.png LR has been saved! Image size:  (75, 75, 3)
# (62, 43, 3)
# (496, 344, 3)
# count:  2801
# 0718.png LR has been saved! Image size:  (62, 43, 3)
# (131, 87, 3)
# (1048, 696, 3)
# count:  2802
# 1086.png LR has been saved! Image size:  (131, 87, 3)
# (162, 119, 3)
# (1296, 952, 3)
# count:  2803
# 0806.png LR has been saved! Image size:  (162, 119, 3)
# (93, 93, 3)
# (744, 744, 3)
# count:  2804
# 0308.png LR has been saved! Image size:  (93, 93, 3)
# (162, 119, 3)
# (1296, 952, 3)
# count:  2805
# 0968.png LR has been saved! Image size:  (162, 119, 3)
# (614, 614, 3)
# (4912, 4912, 3)
# count:  2806
# 0794.png LR has been saved! Image size:  (614, 614, 3)
# (112, 122, 3)
# (896, 976, 3)
# count:  2807
# 0513.png LR has been saved! Image size:  (112, 122, 3)
# (66, 50, 3)
# (528, 400, 3)
# count:  2808
# 0177.png LR has been saved! Image size:  (66, 50, 3)
# (102, 71, 3)
# (816, 568, 3)
# count:  2809
# 1016.png LR has been saved! Image size:  (102, 71, 3)
# (44, 29, 3)
# (352, 232, 3)
# count:  2810
# 0006.png LR has been saved! Image size:  (44, 29, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2811
# 1631.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2812
# 2324.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2813
# 1762.png LR has been saved! Image size:  (75, 75, 3)
# (162, 119, 3)
# (1296, 952, 3)
# count:  2814
# 0025.png LR has been saved! Image size:  (162, 119, 3)
# (31, 37, 3)
# (248, 296, 3)
# count:  2815
# 0188.png LR has been saved! Image size:  (31, 37, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2816
# 2201.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2817
# 2198.png LR has been saved! Image size:  (75, 75, 3)
# (125, 91, 3)
# (1000, 728, 3)
# count:  2818
# 1136.png LR has been saved! Image size:  (125, 91, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2819
# 2206.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2820
# 2901.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2821
# 2500.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2822
# 2273.png LR has been saved! Image size:  (75, 75, 3)
# (122, 92, 3)
# (976, 736, 3)
# count:  2823
# 1144.png LR has been saved! Image size:  (122, 92, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2824
# 1839.png LR has been saved! Image size:  (75, 75, 3)
# (100, 67, 3)
# (800, 536, 3)
# count:  2825
# 0359.png LR has been saved! Image size:  (100, 67, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2826
# 2258.png LR has been saved! Image size:  (75, 75, 3)
# (92, 62, 3)
# (736, 496, 3)
# count:  2827
# 0384.png LR has been saved! Image size:  (92, 62, 3)
# (170, 256, 3)
# (1360, 2048, 3)
# count:  2828
# 0856.png LR has been saved! Image size:  (170, 256, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2829
# 1660.png LR has been saved! Image size:  (75, 75, 3)
# (85, 55, 3)
# (680, 440, 3)
# count:  2830
# 1160.png LR has been saved! Image size:  (85, 55, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2831
# 1608.png LR has been saved! Image size:  (75, 75, 3)
# (78, 62, 3)
# (624, 496, 3)
# count:  2832
# 1272.png LR has been saved! Image size:  (78, 62, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2833
# 2697.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2834
# 2064.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2835
# 1918.png LR has been saved! Image size:  (75, 75, 3)
# (125, 81, 3)
# (1000, 648, 3)
# count:  2836
# 0612.png LR has been saved! Image size:  (125, 81, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2837
# 2699.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2838
# 2517.png LR has been saved! Image size:  (75, 75, 3)
# (96, 72, 3)
# (768, 576, 3)
# count:  2839
# 0848.png LR has been saved! Image size:  (96, 72, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2840
# 1481.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2841
# 2661.png LR has been saved! Image size:  (75, 75, 3)
# (99, 80, 3)
# (792, 640, 3)
# count:  2842
# 0792.png LR has been saved! Image size:  (99, 80, 3)
# (115, 93, 3)
# (920, 744, 3)
# count:  2843
# 0683.png LR has been saved! Image size:  (115, 93, 3)
# (112, 75, 3)
# (896, 600, 3)
# count:  2844
# 0836.png LR has been saved! Image size:  (112, 75, 3)
# (128, 160, 3)
# (1024, 1280, 3)
# count:  2845
# 0286.png LR has been saved! Image size:  (128, 160, 3)
# (356, 237, 3)
# (2848, 1896, 3)
# count:  2846
# 1137.png LR has been saved! Image size:  (356, 237, 3)
# (150, 200, 3)
# (1200, 1600, 3)
# count:  2847
# 0916.png LR has been saved! Image size:  (150, 200, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2848
# 1761.png LR has been saved! Image size:  (75, 75, 3)
# (112, 76, 3)
# (896, 608, 3)
# count:  2849
# 0478.png LR has been saved! Image size:  (112, 76, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2850
# 1553.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2851
# 1403.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2852
# 1491.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2853
# 1493.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2854
# 2395.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2855
# 1738.png LR has been saved! Image size:  (75, 75, 3)
# (45, 60, 3)
# (360, 480, 3)
# count:  2856
# 0077.png LR has been saved! Image size:  (45, 60, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2857
# 2674.png LR has been saved! Image size:  (75, 75, 3)
# (120, 108, 3)
# (960, 864, 3)
# count:  2858
# 1159.png LR has been saved! Image size:  (120, 108, 3)
# (138, 92, 3)
# (1104, 736, 3)
# count:  2859
# 0264.png LR has been saved! Image size:  (138, 92, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2860
# 2111.png LR has been saved! Image size:  (75, 75, 3)
# (634, 720, 3)
# (5072, 5760, 3)
# count:  2861
# 0895.png LR has been saved! Image size:  (634, 720, 3)
# (75, 53, 3)
# (600, 424, 3)
# count:  2862
# 0725.png LR has been saved! Image size:  (75, 53, 3)
# (128, 91, 3)
# (1024, 728, 3)
# count:  2863
# 1251.png LR has been saved! Image size:  (128, 91, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2864
# 2854.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2865
# 1704.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2866
# 1966.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2867
# 1690.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2868
# 1728.png LR has been saved! Image size:  (75, 75, 3)
# (120, 77, 3)
# (960, 616, 3)
# count:  2869
# 0150.png LR has been saved! Image size:  (120, 77, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2870
# 1721.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2871
# 2535.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2872
# 2837.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2873
# 1732.png LR has been saved! Image size:  (75, 75, 3)
# (56, 37, 3)
# (448, 296, 3)
# count:  2874
# 0542.png LR has been saved! Image size:  (56, 37, 3)
# (101, 67, 3)
# (808, 536, 3)
# count:  2875
# 0808.png LR has been saved! Image size:  (101, 67, 3)
# (128, 92, 3)
# (1024, 736, 3)
# count:  2876
# 0989.png LR has been saved! Image size:  (128, 92, 3)
# (116, 75, 3)
# (928, 600, 3)
# count:  2877
# 0370.png LR has been saved! Image size:  (116, 75, 3)
# (750, 500, 3)
# (6000, 4000, 3)
# count:  2878
# 0701.png LR has been saved! Image size:  (750, 500, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2879
# 2577.png LR has been saved! Image size:  (75, 75, 3)
# (162, 119, 3)
# (1296, 952, 3)
# count:  2880
# 0749.png LR has been saved! Image size:  (162, 119, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2881
# 1405.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2882
# 2165.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2883
# 1310.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2884
# 1653.png LR has been saved! Image size:  (75, 75, 3)
# (138, 92, 3)
# (1104, 736, 3)
# count:  2885
# 0349.png LR has been saved! Image size:  (138, 92, 3)
# (80, 60, 3)
# (640, 480, 3)
# count:  2886
# 0721.png LR has been saved! Image size:  (80, 60, 3)
# (265, 176, 3)
# (2120, 1408, 3)
# count:  2887
# 0303.png LR has been saved! Image size:  (265, 176, 3)
# (125, 96, 3)
# (1000, 768, 3)
# count:  2888
# 0979.png LR has been saved! Image size:  (125, 96, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2889
# 2426.png LR has been saved! Image size:  (75, 75, 3)
# (150, 240, 3)
# (1200, 1920, 3)
# count:  2890
# 1010.png LR has been saved! Image size:  (150, 240, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2891
# 1969.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2892
# 2558.png LR has been saved! Image size:  (75, 75, 3)
# (117, 162, 3)
# (936, 1296, 3)
# count:  2893
# 0547.png LR has been saved! Image size:  (117, 162, 3)
# (135, 240, 3)
# (1080, 1920, 3)
# count:  2894
# 0086.png LR has been saved! Image size:  (135, 240, 3)
# (112, 74, 3)
# (896, 592, 3)
# count:  2895
# 0375.png LR has been saved! Image size:  (112, 74, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2896
# 1982.png LR has been saved! Image size:  (75, 75, 3)
# (106, 74, 3)
# (848, 592, 3)
# count:  2897
# 0626.png LR has been saved! Image size:  (106, 74, 3)
# (62, 62, 3)
# (496, 496, 3)
# count:  2898
# 0592.png LR has been saved! Image size:  (62, 62, 3)
# (174, 225, 3)
# (1392, 1800, 3)
# count:  2899
# 0163.png LR has been saved! Image size:  (174, 225, 3)
# (210, 160, 3)
# (1680, 1280, 3)
# count:  2900
# 1059.png LR has been saved! Image size:  (210, 160, 3)
# (93, 59, 3)
# (744, 472, 3)
# count:  2901
# 0262.png LR has been saved! Image size:  (93, 59, 3)
# (187, 125, 3)
# (1496, 1000, 3)
# count:  2902
# 0502.png LR has been saved! Image size:  (187, 125, 3)
# (114, 87, 3)
# (912, 696, 3)
# count:  2903
# 1232.png LR has been saved! Image size:  (114, 87, 3)
# (80, 80, 3)
# (640, 640, 3)
# count:  2904
# 0733.png LR has been saved! Image size:  (80, 80, 3)
# (46, 28, 3)
# (368, 224, 3)
# count:  2905
# 2943.png LR has been saved! Image size:  (46, 28, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2906
# 2049.png LR has been saved! Image size:  (75, 75, 3)
# (60, 106, 3)
# (480, 848, 3)
# count:  2907
# 0766.png LR has been saved! Image size:  (60, 106, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2908
# 2836.png LR has been saved! Image size:  (75, 75, 3)
# (162, 119, 3)
# (1296, 952, 3)
# count:  2909
# 1244.png LR has been saved! Image size:  (162, 119, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2910
# 1530.png LR has been saved! Image size:  (75, 75, 3)
# (135, 240, 3)
# (1080, 1920, 3)
# count:  2911
# 0136.png LR has been saved! Image size:  (135, 240, 3)
# (114, 76, 3)
# (912, 608, 3)
# count:  2912
# 0917.png LR has been saved! Image size:  (114, 76, 3)
# (179, 125, 3)
# (1432, 1000, 3)
# count:  2913
# 0236.png LR has been saved! Image size:  (179, 125, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2914
# 1630.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2915
# 2560.png LR has been saved! Image size:  (75, 75, 3)
# (83, 62, 3)
# (664, 496, 3)
# count:  2916
# 2942.png LR has been saved! Image size:  (83, 62, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2917
# 2029.png LR has been saved! Image size:  (75, 75, 3)
# (125, 200, 3)
# (1000, 1600, 3)
# count:  2918
# 0767.png LR has been saved! Image size:  (125, 200, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2919
# 2462.png LR has been saved! Image size:  (75, 75, 3)
# (468, 374, 3)
# (3744, 2992, 3)
# count:  2920
# 0335.png LR has been saved! Image size:  (468, 374, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2921
# 2693.png LR has been saved! Image size:  (75, 75, 3)
# (208, 125, 3)
# (1664, 1000, 3)
# count:  2922
# 0083.png LR has been saved! Image size:  (208, 125, 3)
# (135, 240, 3)
# (1080, 1920, 3)
# count:  2923
# 0017.png LR has been saved! Image size:  (135, 240, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2924
# 1588.png LR has been saved! Image size:  (75, 75, 3)
# (173, 162, 3)
# (1384, 1296, 3)
# count:  2925
# 0114.png LR has been saved! Image size:  (173, 162, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2926
# 1287.png LR has been saved! Image size:  (75, 75, 3)
# (41, 29, 3)
# (328, 232, 3)
# count:  2927
# 0571.png LR has been saved! Image size:  (41, 29, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2928
# 2140.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2929
# 1430.png LR has been saved! Image size:  (75, 75, 3)
# (158, 162, 3)
# (1264, 1296, 3)
# count:  2930
# 1065.png LR has been saved! Image size:  (158, 162, 3)
# (53, 75, 3)
# (424, 600, 3)
# count:  2931
# 0606.png LR has been saved! Image size:  (53, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2932
# 2331.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2933
# 1284.png LR has been saved! Image size:  (75, 75, 3)
# (119, 92, 3)
# (952, 736, 3)
# count:  2934
# 0938.png LR has been saved! Image size:  (119, 92, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2935
# 1757.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2936
# 2683.png LR has been saved! Image size:  (75, 75, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2937
# 2070.png LR has been saved! Image size:  (75, 75, 3)
# (100, 70, 3)
# (800, 560, 3)
# count:  2938
# 0042.png LR has been saved! Image size:  (100, 70, 3)
# (120, 80, 3)
# (960, 640, 3)
# count:  2939
# 0706.png LR has been saved! Image size:  (120, 80, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2940
# 2592.png LR has been saved! Image size:  (75, 75, 3)
# (132, 100, 3)
# (1056, 800, 3)
# count:  2941
# 0624.png LR has been saved! Image size:  (132, 100, 3)
# (125, 250, 3)
# (1000, 2000, 3)
# count:  2942
# 0827.png LR has been saved! Image size:  (125, 250, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2943
# 1904.png LR has been saved! Image size:  (75, 75, 3)
# (131, 87, 3)
# (1048, 696, 3)
# count:  2944
# 0817.png LR has been saved! Image size:  (131, 87, 3)
# (75, 75, 3)
# (600, 600, 3)
# count:  2945
# 1358.png LR has been saved! Image size:  (75, 75, 3)

# %% [markdown]
# ## Zip the new dataset and copy to google drive

# %%
# %cd /content/datasets/Human_Faces
# Out:
# /content/datasets

# %%
# !zip -r Human_Faces_train_LR_deep_blind.zip Human_Faces_train_LR_deep_blind/
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   adding: Human_Faces_train_LR_deep_blind/X4/2261.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1887.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0505.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1479.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1723.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2757.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2754.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1827.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0385.png (deflated 24%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2734.png (deflated 22%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2806.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1930.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1088.png (deflated 11%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2263.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0632.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0628.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0496.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0884.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1946.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0369.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0715.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1910.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1142.png (deflated 26%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2926.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1173.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0296.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2850.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1118.png (deflated 32%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1523.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1956.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2136.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0511.png (deflated 25%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2458.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0685.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0038.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0325.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0719.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0639.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1191.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2407.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1240.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0185.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2191.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2716.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1179.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0451.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0135.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2098.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2870.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2252.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2743.png (deflated 10%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0881.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1092.png (deflated 23%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1238.png (deflated 24%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0160.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2183.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0976.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2357.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1593.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2343.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2763.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1606.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2586.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2423.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2786.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0887.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1296.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0315.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2372.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2663.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1375.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2685.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1833.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2847.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2770.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0433.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2553.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0008.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0466.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2473.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2302.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2034.png (deflated 8%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2747.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0366.png (deflated 22%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2215.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1970.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0732.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0354.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0472.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0776.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1014.png (deflated 26%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2132.png (deflated 22%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0634.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2653.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2896.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0858.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0246.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2115.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1983.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2163.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2796.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2741.png (deflated 11%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1662.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2012.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0789.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2391.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0705.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2776.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2301.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2320.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1645.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2123.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1652.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1175.png (deflated 25%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0722.png (deflated 23%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2672.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0550.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2416.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0993.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0003.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0929.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1816.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1007.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1467.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0797.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0494.png (deflated 8%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1470.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2224.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1324.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1744.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1154.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0529.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0378.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1544.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0105.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2493.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2748.png (deflated 23%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0950.png (deflated 11%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0844.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1322.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2505.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1399.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0482.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0835.png (deflated 24%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0609.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1079.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2173.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0096.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1929.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0452.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2790.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0688.png (deflated 8%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2895.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0998.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0787.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1081.png (deflated 8%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2767.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0905.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1563.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1353.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2335.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1669.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2127.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2131.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2096.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1954.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1001.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2575.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2825.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2033.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0538.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0122.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0067.png (deflated 23%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1855.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0552.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0517.png (deflated 28%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2349.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2419.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1317.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0554.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1888.png (deflated 11%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0955.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0859.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2605.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2584.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1878.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1166.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2154.png (deflated 22%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2103.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0595.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1458.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2151.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0811.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2549.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1197.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0620.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0428.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1940.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0713.png (deflated 26%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0507.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0498.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2280.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0247.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0581.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0002.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0828.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2819.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0399.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2687.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0947.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1894.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1502.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1972.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0477.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2072.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2382.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0474.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0772.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0899.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2077.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0022.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2182.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0846.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2003.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1658.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0408.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2338.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1183.png (deflated 10%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2013.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0403.png (deflated 8%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0600.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2624.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1963.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0754.png (deflated 8%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1123.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1424.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0413.png (deflated 28%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1749.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2913.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1999.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2869.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2714.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1720.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2826.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2684.png (deflated 22%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1667.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0935.png (deflated 27%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2525.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2459.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2430.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0912.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2936.png (deflated 10%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2398.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1141.png (deflated 26%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2342.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2587.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1595.png (deflated 11%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1268.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2158.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0565.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0124.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0306.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1654.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2176.png (deflated 11%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0544.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1018.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2492.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2820.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1073.png (deflated 23%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0897.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1922.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2336.png (deflated 8%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1891.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1642.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2732.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0121.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2424.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0761.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0338.png (deflated 10%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2369.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0023.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0429.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2138.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1146.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0103.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1811.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0740.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2469.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0098.png (deflated 8%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2030.png (deflated 10%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2195.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1075.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2207.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1994.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1825.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1271.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2678.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0729.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2749.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2432.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2832.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1644.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2557.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0253.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0649.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2355.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2610.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2638.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2286.png (deflated 11%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2402.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2223.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1987.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1666.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2109.png (deflated 8%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2204.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1702.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2093.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0644.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0090.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2481.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1096.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1532.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2475.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1093.png (deflated 25%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1226.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0116.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2834.png (deflated 23%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2810.png (deflated 11%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2001.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0676.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0257.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1639.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2373.png (deflated 26%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0117.png (deflated 24%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0971.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1675.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1935.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1485.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1716.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2328.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1231.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0088.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1984.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0555.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2267.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2727.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1697.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1529.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0534.png (deflated 26%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2495.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1128.png (deflated 22%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0270.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0128.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0009.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1713.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0650.png (deflated 25%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0061.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1487.png (deflated 11%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0946.png (deflated 26%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1741.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2121.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0493.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2097.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0703.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0013.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2631.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1372.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0395.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2027.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0319.png (deflated 25%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1332.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0499.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2390.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2192.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2707.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0289.png (deflated 25%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2389.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1619.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1394.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0857.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0372.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2827.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2555.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2860.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1262.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0964.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2630.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1603.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0108.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2321.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0462.png (deflated 24%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2914.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0567.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1947.png (deflated 22%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1045.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0870.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0148.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2504.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0573.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1589.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2396.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2054.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1711.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2713.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2461.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2509.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2125.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2406.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0580.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1402.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1799.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0320.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1513.png (deflated 11%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1378.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1858.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2360.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0465.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1425.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2573.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1585.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0577.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2318.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1923.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2385.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2898.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0586.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1592.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0965.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0625.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0815.png (stored 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0614.png (deflated 22%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1824.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1577.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2269.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0578.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2580.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2074.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0896.png (deflated 23%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2370.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2019.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1908.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2004.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1911.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1401.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0693.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2789.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2902.png (deflated 22%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2251.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1522.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0710.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1715.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0875.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0224.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2363.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2444.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2813.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2941.png (deflated 26%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1937.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2808.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1311.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0438.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1462.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0265.png (deflated 11%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2651.png (deflated 22%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1700.png (deflated 23%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1996.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1254.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1643.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1250.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1035.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1898.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2437.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0402.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2702.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0560.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1067.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2384.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0387.png (deflated 8%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2234.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0358.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1725.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2884.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1668.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0520.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2835.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1283.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2892.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1009.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2783.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1905.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0723.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0383.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1861.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2420.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2152.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0230.png (deflated 11%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1618.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1015.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0833.png (deflated 10%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2366.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2487.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2325.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1385.png (deflated 22%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0216.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1376.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2815.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0755.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2567.png (deflated 23%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1194.png (deflated 25%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0252.png (deflated 23%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1107.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1883.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0379.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2515.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0636.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2260.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1796.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1554.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2442.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0986.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1591.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1080.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1377.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1964.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2361.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1566.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0492.png (deflated 27%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1906.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0045.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1336.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2944.png (deflated 8%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1731.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1326.png (deflated 31%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0861.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1637.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0862.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2626.png (deflated 11%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0458.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1678.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2122.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2735.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2305.png (deflated 10%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2698.png (deflated 11%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0427.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2792.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2279.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0615.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0653.png (deflated 23%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0011.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1259.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2353.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1917.png (deflated 22%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0692.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2113.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0495.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1519.png (deflated 10%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0894.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0782.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2329.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0076.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2640.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2057.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1912.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0758.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0133.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2619.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1395.png (deflated 10%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2327.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0126.png (deflated 11%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1436.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2101.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0239.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0524.png (deflated 10%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0834.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1303.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1257.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2781.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1469.png (deflated 22%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1109.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1434.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1342.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1363.png (deflated 23%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2656.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2108.png (deflated 10%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1914.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1604.png (deflated 22%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1036.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2413.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1558.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0546.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0659.png (deflated 25%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0907.png (deflated 24%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2590.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0235.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0928.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2906.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0283.png (deflated 23%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0107.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1991.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0178.png (deflated 24%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0339.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0251.png (deflated 27%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0409.png (deflated 22%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0174.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1139.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2032.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1884.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1985.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0310.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1602.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2833.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0591.png (deflated 25%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1975.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2607.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1132.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2566.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2352.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1361.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2472.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2135.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1443.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0344.png (deflated 25%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1475.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1143.png (deflated 24%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1562.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2168.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1147.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1612.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1515.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2229.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0966.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1809.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2818.png (deflated 23%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1082.png (deflated 8%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0969.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0097.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2340.png (deflated 23%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1433.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2295.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0439.png (deflated 24%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1853.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1870.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1521.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0364.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2845.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2312.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2599.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2197.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2932.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1140.png (deflated 10%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0684.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0575.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2399.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0434.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0959.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1832.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1447.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0181.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2532.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1341.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0130.png (deflated 22%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2219.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0260.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2904.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2645.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0134.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1701.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0500.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2574.png (deflated 24%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2422.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2427.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0798.png (deflated 23%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0475.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1278.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2918.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0112.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0841.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1785.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0469.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2669.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1859.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0720.png (deflated 10%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2589.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2571.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2409.png (deflated 22%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1264.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2386.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2576.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0727.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0537.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2563.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1826.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X4/0266.png (deflated 24%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1634.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2933.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1451.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2581.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2284.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X4/2254.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X4/1576.png (deflated 2%)
# ...
#   adding: Human_Faces_train_LR_deep_blind/X8/2289.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1846.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2425.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0780.png (deflated 23%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0020.png (deflated 22%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2153.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1506.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0619.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2510.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1616.png (deflated 10%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0292.png (stored 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0838.png (deflated 23%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2126.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0795.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0330.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2846.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1587.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1028.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1526.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0972.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0627.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1895.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1979.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1448.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1838.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0630.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0590.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2746.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0191.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1076.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0263.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2155.png (stored 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1190.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0255.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2397.png (deflated 8%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0470.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0997.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1958.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1134.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0697.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0574.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2238.png (stored 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2421.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2018.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1024.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2464.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1957.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2562.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0540.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2443.png (stored 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0307.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0175.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1557.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0196.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2314.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2534.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2601.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0089.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1511.png (deflated 11%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2905.png (stored 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2272.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2717.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0095.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1509.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2736.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2642.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2809.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2514.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1290.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0111.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2761.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1334.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1784.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1319.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0883.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1050.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0579.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2247.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0463.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0559.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2296.png (stored 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0228.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1973.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0104.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0209.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1012.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1428.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0523.png (deflated 8%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1736.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0718.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1086.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0806.png (deflated 10%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0308.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0968.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0794.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0513.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0177.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1016.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0006.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1631.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2324.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1762.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0025.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0188.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2201.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2198.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1136.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2206.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2901.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2500.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2273.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1144.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1839.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0359.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2258.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0384.png (stored 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0856.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1660.png (stored 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1160.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1608.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1272.png (deflated 10%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2697.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2064.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1918.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0612.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2699.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2517.png (deflated 10%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0848.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1481.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2661.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0792.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0683.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0836.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0286.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1137.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0916.png (deflated 22%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1761.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0478.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1553.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1403.png (deflated 11%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1491.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1493.png (stored 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2395.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1738.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0077.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2674.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1159.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0264.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2111.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0895.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0725.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1251.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2854.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1704.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1966.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1690.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1728.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0150.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1721.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2535.png (stored 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2837.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1732.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0542.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0808.png (deflated 11%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0989.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0370.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0701.png (deflated 35%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2577.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0749.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1405.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2165.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1310.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1653.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0349.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0721.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0303.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0979.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2426.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1010.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1969.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2558.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0547.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0086.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0375.png (deflated 12%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1982.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0626.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0592.png (deflated 16%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0163.png (deflated 23%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1059.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0262.png (deflated 10%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0502.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1232.png (deflated 8%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0733.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2943.png (stored 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2049.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0766.png (deflated 4%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2836.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1244.png (deflated 7%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1530.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0136.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0917.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0236.png (deflated 15%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1630.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2560.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2942.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2029.png (deflated 9%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0767.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2462.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0335.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2693.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0083.png (deflated 17%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0017.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1588.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0114.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1287.png (deflated 13%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0571.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2140.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1430.png (deflated 5%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1065.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0606.png (deflated 2%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2331.png (deflated 14%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1284.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0938.png (deflated 21%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1757.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2683.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2070.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0042.png (deflated 3%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0706.png (deflated 18%)
#   adding: Human_Faces_train_LR_deep_blind/X8/2592.png (deflated 0%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0624.png (deflated 20%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0827.png (deflated 6%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1904.png (deflated 19%)
#   adding: Human_Faces_train_LR_deep_blind/X8/0817.png (deflated 1%)
#   adding: Human_Faces_train_LR_deep_blind/X8/1358.png (deflated 2%)

# %%
import os

# Lấy đường dẫn đến file zip
file_path = "/content/datasets/Human_Faces/Human_Faces_train_LR_deep_blind.zip"

# Lấy thông tin về file zip
file_info = os.stat(file_path)

# In ra độ lớn của file zip
print(file_info.st_size/2**30, "gb")
# Out:
# 0.2687787553295493 gb

# %%
# %cp -rf Human_Faces_train_LR_deep_blind.zip /content/drive/MyDrive/Datasets/train/Human_Faces_train_LR_deep_blind.zip
