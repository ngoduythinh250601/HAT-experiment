# %%
import matplotlib.pyplot as plt

num = 12

psnr_HATS_ML_SRx4_Set5 = [31.3660, 31.9785, 32.1172, 32.1966, 32.2135, 32.2431, 32.2529, 32.2451, 32.2580, 32.2568, 32.2450, 32.2298, 32.2521]
ssim_HATS_ML_SRx4_Set5 = [0.8791, 0.8872, 0.8888, 0.8897, 0.8897, 0.8903, 0.8900, 0.8897, 0.8900, 0.8895, 0.8895, 0.8890, 0.8895]
psnr_HATS_ML_SRx4_Set14 = [28.0307, 28.3803, 28.4746, 28.5400, 28.5723, 28.5838, 28.6010, 28.6080, 28.6346, 28.6591, 28.6552, 28.6475, 28.6563]
ssim_HATS_ML_SRx4_Set14 = [0.7624, 0.7703, 0.7720, 0.7731, 0.7742, 0.7736, 0.7748, 0.7748, 0.7758, 0.7760, 0.7762, 0.7760, 0.7765]

psnr_HATS_PM_SRx4_Set5 = [31.2682, 31.9402, 32.1788, 32.3162, 32.3757, 32.4477, 32.4818, 32.5208, 32.5112, 32.5193, 32.5086, 32.5233, 32.5495]
ssim_HATS_PM_SRx4_Set5 = [0.8809, 0.8913, 0.8948, 0.8968, 0.8977, 0.8987, 0.8991, 0.8997, 0.8998, 0.9000, 0.9000, 0.9000, 0.9003]
psnr_HATS_PM_SRx4_Set14 = [28.0189, 28.4455, 28.6242, 28.7321, 28.7537, 28.8211, 28.8497, 28.8875, 28.8878, 28.9032, 28.9121, 28.9193, 28.9117]
ssim_HATS_PM_SRx4_Set14 = [0.7677, 0.7778, 0.7819, 0.7842, 0.7849, 0.7860, 0.7871, 0.7880, 0.7883, 0.7885, 0.7888, 0.7887, 0.7887]

psnr_HATS_PL_SRx4_Set5 = [26.2168, 26.1869, 25.7176, 25.2240, 24.6728, 24.5489, 24.5893, 24.5330, 24.6092, 24.6448, 24.8299, 24.8794, 24.8312]
ssim_HATS_PL_SRx4_Set5 = [0.6333, 0.6479, 0.6218, 0.5894, 0.5512, 0.5438, 0.5467, 0.5420, 0.5389, 0.5429, 0.5546, 0.5584, 0.5556]
psnr_HATS_PL_SRx4_Set14 = [23.5847, 23.4530, 23.2389, 22.9286, 22.5791, 22.3852, 22.4535, 22.4926, 22.6008, 22.6351, 22.7166, 22.7204, 22.7208]
ssim_HATS_PL_SRx4_Set14 = [0.5016, 0.5027, 0.4849, 0.4628, 0.4386, 0.4288, 0.4295, 0.4333, 0.4352, 0.4383, 0.4433, 0.4440, 0.4441]

psnr_HATS_OR_SRx4_Set5 = [31.4314, 32.0600, 32.2725, 32.3699, 32.4108, 32.4521, 32.4717, 32.4911, 32.5221, 32.5115, 32.5152, 32.5304, 32.5212]
ssim_HATS_OR_SRx4_Set5 = [0.8840, 0.8933, 0.8963, 0.8977, 0.8985, 0.8992, 0.8996, 0.9001, 0.9003, 0.9004, 0.9006, 0.9007, 0.9007]
psnr_HATS_OR_SRx4_Set14 = [28.0952, 28.5066, 28.6504, 28.7397, 28.7881, 28.8400, 28.8722, 28.8834, 28.8913, 28.9067, 28.9148, 28.9277, 28.9322]
ssim_HATS_OR_SRx4_Set14 = [0.7705, 0.7800, 0.7833, 0.7854, 0.7866, 0.7877, 0.7889, 0.7891, 0.7895, 0.7899, 0.7901, 0.7904, 0.7904]


psnr_HATS_ML_SRx8_Set5 = [25.9743, 26.4243, 26.5667, 26.6781, 26.7240, 26.7869, 26.8291, 26.8470, 26.8503, 26.8556, 26.8899, 26.8836, 26.8734]
ssim_HATS_ML_SRx8_Set5 = [0.7245, 0.7468, 0.7537, 0.7591, 0.7614, 0.7646, 0.7657, 0.7663, 0.7666, 0.7672, 0.7685, 0.7682, 0.7681]
psnr_HATS_ML_SRx8_Set14 = [24.1154, 24.4329, 24.5585, 24.6491, 24.7160, 24.7743, 24.8182, 24.8264	, 24.8385, 24.8384, 24.8616, 24.8529, 24.8608]
ssim_HATS_ML_SRx8_Set14 = [0.6051, 0.6164, 0.6210,  0.6239, 0.6266,  0.6285, 0.6304, 0.6307	, 0.6305, 0.6310, 0.6311, 0.6311, 0.6316]

psnr_HATS_PM_SRx8_Set5 = [26.0694, 26.4763, 26.6731, 26.7932, 26.8644, 26.8916, 26.9374, 26.9594, 26.9619	, 26.9819, 26.9865, 26.9985, 27.0053]
ssim_HATS_PM_SRx8_Set5 = [0.7316, 0.7519, 0.7610, 0.7664, 0.7694, 0.7713, 0.7735, 0.7743, 0.7748, 0.7756, 0.7763, 0.7769, 0.7772]
psnr_HATS_PM_SRx8_Set14 = [24.2310, 24.5418, 24.6856, 24.7685, 24.8101, 24.8558, 24.8816, 24.9151, 24.9452, 24.9491, 24.9623, 24.9615, 24.9665]
ssim_HATS_PM_SRx8_Set14 = [0.6136, 0.6252, 0.6304, 0.6338, 0.6355, 0.6370, 0.6381, 0.6390, 0.6396	, 0.6400, 0.6405, 0.6406, 0.6406]

# psnr_HATS_PL_SRx8_Set5 = [, , , , , , , , , , , , ]
# ssim_HATS_PL_SRx8_Set5 = [, , , , , , , , , , , , ]
# psnr_HATS_PL_SRx8_Set14 = [, , , , , , , , , , , , ]
# ssim_HATS_PL_SRx8_Set14 = [, , , , , , , , , , , , ]

psnr_HATS_OR_SRx8_Set5 = [26.0673, 26.5161, 26.6954, 26.7922, 26.8521, 26.9044, 26.9469, 26.9770, 26.9778, 27.0009, 27.0188, 27.0191, 27.0292]
ssim_HATS_OR_SRx8_Set5 = [0.7313, 0.7528, 0.7617, 0.7660, 0.7688, 0.7715, 0.7732, 0.7743, 0.7748, 0.7758, 0.7767, 0.7767, 0.7772]
psnr_HATS_OR_SRx8_Set14 = [24.2123, 24.5392, 24.6627, 24.7375, 24.8165, 24.8641, 24.9168, 24.9365, 24.9352, 24.9519, 24.9638, 24.9574, 24.9616]
ssim_HATS_OR_SRx8_Set14 = [0.6128, 0.6252, 0.6302, 0.6331, 0.6358, 0.6376, 0.6399, 0.6407, 0.6408, 0.6412, 0.6416, 0.6415, 0.6417]


iter = [i*20000 for i in range(1, num + 1)]

num += 1
iter.append(250000)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Vẽ biểu đồ
plt.plot(iter, psnr_HATS_OR_SRx4_Set5[:num], label="HAT-S original")
plt.plot(iter, psnr_HATS_PM_SRx4_Set5[:num], label="HAT-S + Patch-Mosaic")
# plt.plot(iter, psnr_HATS_PL_SRx4_Set5[:num], label="HAT-S + Perceptual Loss")
plt.plot(iter, psnr_HATS_ML_SRx4_Set5[:num], label="HAT-S + MixLosses Loss")
plt.xlabel("Iter")
plt.ylabel("PSNR")
plt.title("PSNR curve on Set5, upscale x4")
plt.legend()

# Hiển thị biểu đồ
plt.show()

# %%
# Vẽ biểu đồ
plt.plot(iter, ssim_HATS_OR_SRx4_Set5[:num], label="HAT-S original")
plt.plot(iter, ssim_HATS_PM_SRx4_Set5[:num], label="HAT-S + Patch-Mosaic")
# plt.plot(iter, ssim_HATS_PL_SRx4_Set5[:num], label="HAT-S + Perceptual Loss")
plt.plot(iter, ssim_HATS_ML_SRx4_Set5[:num], label="HAT-S + MixLosses Loss")
plt.xlabel("Iter")
plt.ylabel("SSIM")
plt.title("SSIM curve on Set5, upscale x4")
plt.legend()

# Hiển thị biểu đồ
plt.show()

# %%
# Vẽ biểu đồ
plt.plot(iter, psnr_HATS_OR_SRx4_Set14[:num], label="HAT-S original")
plt.plot(iter, psnr_HATS_PM_SRx4_Set14[:num], label="HAT-S + Patch-Mosaic")
# plt.plot(iter, psnr_HATS_PL_SRx4_Set14[:num], label="HAT-S + Perceptual Loss")
plt.plot(iter, psnr_HATS_ML_SRx4_Set14[:num], label="HAT-S + MixLosses Loss")
plt.xlabel("Iter")
plt.ylabel("PSNR")
plt.title("PSNR curve on Set14, upscale x4")
plt.legend()

# Hiển thị biểu đồ
plt.show()

# %%
# Vẽ biểu đồ
plt.plot(iter, ssim_HATS_OR_SRx4_Set14[:num], label="HAT-S original")
plt.plot(iter, ssim_HATS_PM_SRx4_Set14[:num], label="HAT-S + Patch-Mosaic")
# plt.plot(iter, ssim_HATS_PL_SRx4_Set14[:num], label="HAT-S + Perceptual Loss")
plt.plot(iter, ssim_HATS_ML_SRx4_Set14[:num], label="HAT-S + MixLosses Loss")
plt.xlabel("Iter")
plt.ylabel("SSIM")
plt.title("SSIM curve on Set14, upscale x4")
plt.legend()

# Hiển thị biểu đồ
plt.show()

# %%
# Vẽ biểu đồ
plt.plot(iter, psnr_HATS_OR_SRx8_Set5[:num], label="HAT-S original")
plt.plot(iter, psnr_HATS_PM_SRx8_Set5[:num], label="HAT-S + Patch-Mosaic")
# plt.plot(iter, psnr_HATS_PL_SRx8_Set5[:num], label="HAT-S + Perceptual Loss")
plt.plot(iter, psnr_HATS_ML_SRx8_Set5[:num], label="HAT-S + MixLosses Loss")
plt.xlabel("Iter")
plt.ylabel("PSNR")
plt.title("PSNR curve on Set5, upscale x8")
plt.legend()

# Hiển thị biểu đồ
plt.show()

# %%
# Vẽ biểu đồ
plt.plot(iter, ssim_HATS_OR_SRx8_Set5[:num], label="HAT-S original")
plt.plot(iter, ssim_HATS_PM_SRx8_Set5[:num], label="HAT-S + Patch-Mosaic")
# plt.plot(iter, ssim_HATS_PL_SRx8_Set5[:num], label="HAT-S + Perceptual Loss")
plt.plot(iter, ssim_HATS_ML_SRx8_Set5[:num], label="HAT-S + MixLosses Loss")
plt.xlabel("Iter")
plt.ylabel("SSIM")
plt.title("SSIM curve on Set5, upscale x8")
plt.legend()

# Hiển thị biểu đồ
plt.show()

# %%
# Vẽ biểu đồ
plt.plot(iter, psnr_HATS_OR_SRx8_Set14[:num], label="HAT-S original")
plt.plot(iter, psnr_HATS_PM_SRx8_Set14[:num], label="HAT-S + Patch-Mosaic")
# plt.plot(iter, psnr_HATS_PL_SRx8_Set14[:num], label="HAT-S + Perceptual Loss")
plt.plot(iter, psnr_HATS_ML_SRx8_Set14[:num], label="HAT-S + MixLosses Loss")
plt.xlabel("Iter")
plt.ylabel("PSNR")
plt.title("PSNR curve on Set14, upscale x8")
plt.legend()

# Hiển thị biểu đồ
plt.show()

# %%
# Vẽ biểu đồ
plt.plot(iter, ssim_HATS_OR_SRx8_Set14[:num], label="HAT-S original")
plt.plot(iter, ssim_HATS_PM_SRx8_Set14[:num], label="HAT-S + Patch-Mosaic")
# plt.plot(iter, ssim_HATS_PL_SRx8_Set14[:num], label="HAT-S + Perceptual Loss")
plt.plot(iter, ssim_HATS_ML_SRx8_Set14[:num], label="HAT-S + MixLosses Loss")
plt.xlabel("Iter")
plt.ylabel("SSIM")
plt.title("SSIM curve on Set14, upscale x8")
plt.legend()

# Hiển thị biểu đồ
plt.show()
