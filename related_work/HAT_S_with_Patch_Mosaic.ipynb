# %% [markdown]
# # Clone git repo and install requirements

# %%
# !git clone https://github.com/XPixelGroup/HAT.git
# Out:
# Cloning into 'HAT'...
# remote: Enumerating objects: 410, done.
# remote: Counting objects: 100% (251/251), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 410 (delta 196), reused 155 (delta 122), pack-reused 159
# Receiving objects: 100% (410/410), 20.73 MiB | 29.43 MiB/s, done.
# Resolving deltas: 100% (226/226), done.

# %%
# %cd HAT
# Out:
# /content/HAT

# %%
# !pip install -r requirements.txt
# !python setup.py develop
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 7.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 19.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 88.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 33.1 MB/s eta 0:00:00
# ...
#   Created wheel for basicsr: filename=basicsr-1.3.4.9-py3-none-any.whl size=194421 sha256=87b8d76513abfa28404427836b1cf354432fb012c294786f47840ba67243c01c
#   Stored in directory: /root/.cache/pip/wheels/37/19/97/8206d928857f2ef0625cb621b689005610515b4841be4e5ddb
# Successfully built basicsr
# ...
# /usr/local/lib/python3.10/dist-packages/setuptools/__init__.py:84: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
# !!
#
# ...

# %%
# !pwd
# Out:
# /content/HAT

# %% [markdown]
# # Process data

# %% [markdown]
# ## Mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Process train dataset

# %%
# !unzip /content/drive/MyDrive/Datasets/train/DIV2K_train_HR_Mosaic.zip -d /content/HAT/datasets/DIV2K
# !unzip /content/drive/MyDrive/Datasets/train/DIV2K_train_LR_bicubic_X4_Mosaic.zip -d /content/HAT/datasets/DIV2K
# Out:
# Archive:  /content/drive/MyDrive/Datasets/train/DIV2K_train_HR_Mosaic.zip
#    creating: /content/HAT/datasets/DIV2K/DIV2K_train_HR/
#   inflating: /content/HAT/datasets/DIV2K/DIV2K_train_HR/0480.png
#   inflating: /content/HAT/datasets/DIV2K/DIV2K_train_HR/0540.png
#   inflating: /content/HAT/datasets/DIV2K/DIV2K_train_HR/0257.png
#   inflating: /content/HAT/datasets/DIV2K/DIV2K_train_HR/0646.png
#   inflating: /content/HAT/datasets/DIV2K/DIV2K_train_HR/0842.png
#   inflating: /content/HAT/datasets/DIV2K/DIV2K_train_HR/0511.png
#   inflating: /content/HAT/datasets/DIV2K/DIV2K_train_HR/0644.png
#   inflating: /content/HAT/datasets/DIV2K/DIV2K_train_HR/0570.png
#   inflating: /content/HAT/datasets/DIV2K/DIV2K_train_HR/0569.png
#   inflating: /content/HAT/datasets/DIV2K/DIV2K_train_HR/0457.png
#   inflating: /content/HAT/datasets/DIV2K/DIV2K_train_HR/0608.png
#   inflating: /content/HAT/datasets/DIV2K/DIV2K_train_HR/0663.png
# ...

# %% [markdown]
# ## Unzip validation dataset

# %%
# !unzip /content/drive/MyDrive/Datasets/test/Set5.zip -d /content/HAT/datasets
# !unzip /content/drive/MyDrive/Datasets/test/Set14.zip -d /content/HAT/datasets
# Out:
# Archive:  /content/drive/MyDrive/Datasets/test/Set5.zip
#    creating: /content/HAT/datasets/Set5/
#    creating: /content/HAT/datasets/Set5/GTmod12/
#   inflating: /content/HAT/datasets/Set5/GTmod12/baby.png
#   inflating: /content/HAT/datasets/Set5/GTmod12/bird.png
#   inflating: /content/HAT/datasets/Set5/GTmod12/butterfly.png
#   inflating: /content/HAT/datasets/Set5/GTmod12/head.png
#   inflating: /content/HAT/datasets/Set5/GTmod12/woman.png
#    creating: /content/HAT/datasets/Set5/LRbicx2/
#   inflating: /content/HAT/datasets/Set5/LRbicx2/baby.png
#   inflating: /content/HAT/datasets/Set5/LRbicx2/bird.png
#   inflating: /content/HAT/datasets/Set5/LRbicx2/butterfly.png
#   inflating: /content/HAT/datasets/Set5/LRbicx2/head.png
#   inflating: /content/HAT/datasets/Set5/LRbicx2/woman.png
#    creating: /content/HAT/datasets/Set5/LRbicx3/
#   inflating: /content/HAT/datasets/Set5/LRbicx3/baby.png
#   inflating: /content/HAT/datasets/Set5/LRbicx3/bird.png
# ...

# %% [markdown]
# # Training

# %%
# !mkdir /content/HAT/experiments/train_HAT-S_SRx4_Patch-Mosaic/
# !mkdir /content/HAT/experiments/train_HAT-S_SRx4_Patch-Mosaic/models/
# !mkdir /content/HAT/experiments/train_HAT-S_SRx4_Patch-Mosaic/training_states/

# %% [markdown]
# Copy checkpoint to the required folder

# %%
# !cp -r /content/drive/MyDrive/Results/superresolution/train_HAT-S_SRx4_Patch-Mosaic/models/net_g_95000.pth /content/HAT/experiments/train_HAT-S_SRx4_Patch-Mosaic/models/net_g_95000.pth
# !cp -r /content/drive/MyDrive/Results/superresolution/train_HAT-S_SRx4_Patch-Mosaic/training_states/95000.state /content/HAT/experiments/train_HAT-S_SRx4_Patch-Mosaic/training_states/95000.state

# %% [markdown]
# Upload train_HAT-S_SRx4_Patch-Mosaic.yml into /content/HAT/options/train directory and modify checkpoint dir and total_iter

# %%
# !python hat/train.py -opt options/train/train_HAT-S_SRx4_Patch-Mosaic.yml
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(
# Disable distributed.
# pretrain_network path will be ignored during resuming.
# Set pretrain_network_g to /content/HAT/experiments/train_HAT-S_SRx4_Patch-Mosaic/models/net_g_95000.pth
# 2023-10-23 09:12:44,090 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
# ...

# %% [markdown]
# # Save checkpoint

# %%
# %cp -rf /content/HAT/experiments/train_HAT-S_SRx4_Patch-Mosaic /content/drive/MyDrive/Results/superresolution
